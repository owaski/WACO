# %%
import os
import re
import random

import pandas as pd
import torchaudio
from tqdm import tqdm
import csv

# %%
def load_df_from_tsv(path: str, enc='utf-8'):
    return pd.read_csv(
        path,
        sep="\t",
        header=0,
        encoding=enc,
        escapechar="\\",
        quoting=csv.QUOTE_NONE,
        na_filter=False,
    )


def save_df_to_tsv(dataframe, path):
    dataframe.to_csv(
        path,
        sep="\t",
        header=True,
        index=False,
        encoding="utf-8",
        escapechar="\\",
        quoting=csv.QUOTE_NONE,
    )

# %%
path_to_iwslt_mt_en = "XXX"
path_to_mustc = "XXX"
path_to_commonvoice13 = "XXX"

# %% [markdown]
# # ASR from IWSLT

# %%
root = '{}/MT_EN'.format(path_to_iwslt_mt_en)

# %%
asr_audio_root = os.path.join(root, 'mt_only', 'Audio')
asr_root = os.path.join(root, 'mt_only', 'Transcription', 'Malti')
new_wav_root = '{}/mt-en/data/asr/wav'.format(path_to_mustc)
mustc_root = path_to_mustc

# %%
new_wav_root
# Out:
# '/mnt/data7/siqiouyang/datasets/must-c-v1.0/mt-en/data/asr/wav'

# %%
def detect_annotator(items):
    common_suffix = ""
    for item in items:
        # print(common_suffix, item)
        if 'annotator' in item.lower() or 'sp' in item.lower()[-3:] or 'speaker' in item.lower():
            if common_suffix == "":
                common_suffix = item
            else:
                for j in range(min(len(common_suffix), len(item))):
                    if common_suffix[len(common_suffix) - j - 1] != item[len(item) - j - 1] and not common_suffix[len(common_suffix) - j - 1].isdigit():
                        common_suffix = common_suffix[len(common_suffix) - j:]
                        break
    return common_suffix

# %%
def detect_machine(items):
    common_suffix = ""
    for item in items:
        if 'Machine' in item:
            if common_suffix == "":
                common_suffix = item
            else:
                for j in range(min(len(common_suffix), len(item))):
                    if common_suffix[len(common_suffix) - j - 1] != item[len(item) - j - 1] and not common_suffix[len(common_suffix) - j - 1].isdigit():
                        common_suffix = common_suffix[len(common_suffix) - j:]
                        break
    return common_suffix

# %%
def equal(s1, s2):
    if len(s1) != len(s2):
        return False
    for u, v in zip(s1, s2):
        if u != v and not u.isdigit():
            return False
    return True

# %%
def make_df(quads, wav_id, speaker_id, wav, rate):
    df = pd.DataFrame(columns=['id', 'audio', 'n_frames', 'src_text', 'speaker', 'src_lang'])

    id = []
    audio = []
    n_frames = []
    src_text = []
    speaker = []
    src_lang = []

    os.makedirs(new_wav_root, exist_ok=True)
    for idx, q in enumerate(quads):
        duration = q[1] - q[0]
        text = re.sub('<.*>', ' ', q[3]).strip()
        if duration > 0.5 and text != "" and duration < 30 and '/' not in text:
            subwav_id = wav_id + '_spk_{}_{}'.format(speaker_id, idx)
            wav_s, wav_e = int(q[0] * rate), int(q[1] * rate)

            # if 'dia_task_pics02_13f_10m_spk_0' in subwav_id:
            #     print(subwav_id, wav_s, wav_e, len(wav))

            torchaudio.save(os.path.join(new_wav_root, subwav_id + '.wav'), wav[wav_s : wav_e].unsqueeze(0), rate)
            # torchaudio.save(os.path.join('mt_en', subwav_id + '.wav'), wav[wav_s : wav_e].unsqueeze(0), rate)
            
            id.append(subwav_id)
            audio.append('mt-en/data/asr/wav/{}.wav'.format(subwav_id))
            n_frames.append(wav_e - wav_s)
            src_text.append(text)
            speaker.append(q[2])
            src_lang.append('mt')

            print(subwav_id, q[0], q[1], text, sep='\t')

    df['id'] = id
    df['audio'] = audio
    df['n_frames'] = n_frames
    df['src_text'] = src_text
    df['speaker'] = speaker
    df['src_lang'] = src_lang
    return df

# %%
all_df = None

# %%
sum_d = 0
for fn in os.listdir(asr_root):
    print(fn)

    with open(os.path.join(asr_root, fn), 'r', encoding='utf-16') as r:
        text = r.read()
    
    items = text.split('\t')
    
    # str_ann = detect_annotator(items[3::3])
    # str_mac = detect_machine(items[3::3])

    str_mac = detect_annotator(items[3::3])
    str_ann = detect_machine(items[3::3])

    quads = []

    for i in range(3, len(items), 3):
        if equal(items[i][-len(str_ann):], str_ann):
            if i + 3 < len(items):
                if equal(items[i + 3][-len(str_ann):], str_ann):
                    text = items[i + 3][:-len(str_ann)]
                elif equal(items[i + 3][-len(str_mac):], str_mac):
                    text = items[i + 3][:-len(str_mac)]
                else:
                    text = items[i + 3]
                    # print(text)

                quads.append((float(items[i + 1]), float(items[i + 2]), items[i][-len(str_ann):], text))

    quads = sorted(quads)
    annotators = set([q[2] for q in quads])
    print(annotators)

    wav, rate = torchaudio.load(os.path.join(asr_audio_root, fn[:-4] + '.wav'))
    resampled_wav = torchaudio.functional.resample(wav, orig_freq=rate, new_freq=16000)
    if wav.size()[0] == 2 and len(annotators) == 2:
        for i in range(2):
            cur_df = make_df([q for q in quads if str(i + 1) in q[2]], fn[:-4], i, resampled_wav[i], 16000)
            all_df = cur_df if all_df is None else pd.concat([all_df, cur_df], ignore_index=True)
    elif wav.size()[0] == 1 and len(annotators) == 1:
        cur_df = make_df(quads, fn[:-4], 0, resampled_wav[0], 16000)
        all_df = cur_df if all_df is None else pd.concat([all_df, cur_df], ignore_index=True)
    elif wav.size()[0] == 2 and len(annotators) == 1:
        cur_df = make_df(quads, fn[:-4], 0, resampled_wav[0] + resampled_wav[1], 16000)
        all_df = cur_df if all_df is None else pd.concat([all_df, cur_df], ignore_index=True)
    else:
        pass
# Out:
# dia_discuss_topic05_18f_12m.tsv
# {'Spk 1 Machine', 'Spk 2 Machine'}
# dia_discuss_topic05_18f_12m_spk_0_4	13.187847314404472	15.58	eżattament e
# dia_discuss_topic05_18f_12m_spk_0_8	19.3	21.14	tirrifletti ill-karattru ta' dak li jkun u
# dia_discuss_topic05_18f_12m_spk_0_10	22.92	25.86	u m'għandu jkun hemm ebda stigma fejn il-utatus huma x' inhuma ttatus
# dia_discuss_topic05_18f_12m_spk_0_13	32.76	34.7	dil-ħaġa li jien naf pereżempju jiġi jgħidulek f' ċerti postijiet tax-xogħol ma jaċċettawx nies bit-tatus għalija msorija injolenza l-kbira naraha diskriminazzjoni kbira
# dia_discuss_topic05_18f_12m_spk_0_15	37.88	49.56	għax bnidem li jkollu tatus kapaċi jkun
# dia_discuss_topic05_18f_12m_spk_0_17	51.04	53.42	kompetenti fix-xogħol
# dia_discuss_topic05_18f_12m_spk_0_21	57.5	58.82	jekk bniedem jagħmel tator jagħmilha
# dia_discuss_topic05_18f_12m_spk_0_23	60.8	62.98	ħa bħala gost u aħdan bħal meta tagħmel heir stile bħal meta tagħmel tilbess ċertu ħwejjeġ
# dia_discuss_topic05_18f_12m_spk_0_25	64.76	71.4	jew forsi anka jkun rikordju ta' xi ħaġa
# dia_discuss_topic05_18f_12m_spk_0_29	77.3	79.02	le jiena mama jaffettwanix bniedem bit-tadusa n
# dia_discuss_topic05_18f_12m_spk_0_31	80.62	83.2	blitta tużuminirominaż għidtgħidtloa us-sinċiera ajiġifieri jekk pereżempju jiena naċċetika
# dia_discuss_topic05_18f_12m_spk_0_33	84.56	90.14	lok naċċetta lill-perentaturi tal-cateathure ma nara xejn ħażin imma ma jadnux ħa jkollu ixi l-unika tastua ma' sfal na idejh u ngħidlu x' kiex se ħasal affar jitejk tħjtkom minn ema ja nara strampa anaf jien naf naf min għandu vja kruċi sħiħa fuq dahru pereżempju imma li qadt nara stramba ġiti li jaħġeb it-testi pereżempju jew inkella jekk għandek jien naf xi statuta ta' xi pinocgerlyw acfuq fuq fuq spallter jewe fuq saqajk u mbagħad jilbex xorġ si skola nara naqra inuna roprijiet jiġifieri hemm l-għażla tat-tlieta ukoll ħna jiġifierijekk jekk int qed tgħid ikollok tatun nap-inappropjata għandha titgħatta mill-ħwejjeġ
# dia_discuss_topic05_18f_12m_spk_0_39	174.6	176.74	m' għandix għalfejn pieni tiegħi m' għandhix titgħattha m' għandix a kieku m'għandux għalfejn jitkaża jew jew m' għandux għalfejn influwenza ruħu b' mod ħażin fuq fuq l-individwu
# dia_discuss_topic05_18f_12m_spk_0_43	189.56	210.18	qisek jaħk ti l-idea li la jkollok settur bla ma trid ħa tiġi iġġudikat għad hawn nies jaħsbu li hija xi ħaġa li ont le tagħmilha ma tistax titnaħħa li issa huwa argument skorrett ħafna minħabba l-fatt illum hawn lejn żep
# dia_discuss_topic05_18f_12m_spk_0_45	211.44	224.9	tredment uġieli kien hawn pereżempju n-nies kienu f'relazzjonijiet għamlu għamlu tatu tal-partner tagħhom li mbagħad ħassru ġennata kbira hu ħassru u e u dana
# dia_discuss_topic05_18f_12m_spk_0_47	226.36	236.86	illum jisħunaħuh ije sa-ġrejs tar naħseb għax in ġieli ngħid dħal l-iskar iva fil-fatti ġieli jagħmlu oħra fuqha emm jaktuha jagħmlu oħra fuqha mbagħad u ha min jikkoreġihom mill-ewwel direttament imma ovvjament irid rid tkun itik id-diżimpreċeventi biex tagħmel he
# dia_discuss_topic05_18f_12m_spk_0_51	257.3	258.26	siġa però għandi ħafna mill-bieb tiegħi għandhom tatus u għandi ħbieb li għandhom tatus
# dia_discuss_topic05_18f_12m_spk_0_53	260.76	265.7	enormi jiġifieri dak it-tip ħamsin sittin fil-mija ta' ġisimhu dak it-tip ek
# dia_discuss_topic05_18f_12m_spk_0_62	284.88	298.16	hekk hemm ċerta llukk kompluta li hija naqra intiminanti ma nafx x' inhiex ni inix għandix idea żbaljata imma jidhirli li hawn malta fil-kostituzzjoni ta'tuse fil-wiċċ ma jistax ikollok en diversi pace
# dia_discuss_topic05_18f_12m_spk_0_64	299.56	313.1	m' iniex ċert jiena smajt hawn waqtu waqt diskussjoni u
# dia_discuss_topic05_18f_12m_spk_0_66	314.36	318.7	ma kontx fiha d-diskussjoni għax kienet fuq ir-radiow jiġifieri u xi ħadd qħabda dal-kumment u għid dik l-impressjoni ma nafx jekk hux vera eħe li fil-wiċċ mhux suppost ikollok qatt ma rajt ataimma lejn arna-rajt rajt kemm-il darba jien forsi li jinħatana imma mamhux f' wiċċi biżifil-wiċċ li hewn fuq il-moħħ qegħdin ngħidu fuq il-wardiet rajt rinde iva imrajtu u jibqgħu niżlen
# dia_discuss_topic05_18f_12m_spk_0_68	320.76	344.74	issa nfhimni inti trid tqis inti trid tqis i hawn f' dail-pajjiż hawn ħafna li-liġijiet li mhumiex infurzati qed tifhem kapaċi dinja waħda minnhom
# dia_discuss_topic05_18f_12m_spk_0_70	346.26	356.4	hemm jien lanqas tikk i ma nafx sinċerament ma nafx x' inhija jekk teżisti verek jekk nerġa' ngħid m' iniex żbaljat ma nafx x' inhuwa il-il-il-kunċett warajha sinċerma għax fil-vetà binhemm li jkollu tatum iktar jintgħaraf ġo wiċċu ħe ħa ħa ħa ħa ħa jiġifieri ħi iktar jieu itar i le jiġiefi ma tistax taħttaħbil-wiċċ għax xi ħaġa din mhux maskina jew ħelmit dħalt biha
# dia_discuss_topic05_18f_12m_spk_0_72	357.96	384.8	xi minn post umgħarfek ħatt x e
# dia_discuss_topic05_18f_12m_spk_0_74	386.18	389.1	le wagħid tajb le ma m 'għinlhix iddeħera dika
# dia_discuss_topic05_18f_12m_spk_0_78	393.82	398.74	għandna ħafna nisa għandho tetuts jiġifieri kkumurissima jiġifieri kumpaniji kolla li l qadem gal-fammija akważi pti ta ditigħi komunissimli kollha tatuż imma eħe normamentux dik it-tip li hija adostrim sħiħa ehe hekk k va jkollhom dik it-tetuż żgħar pereżempju ma' saqajhom iħenaqra differenti lejra meta għaddejja kull sena ngħaddi mill-fażi ngħid irribtgħidtuko qatt ma qatt ma nagħmilha
# dia_discuss_topic05_18f_12m_spk_0_80	400.58	422.3	ħe-ħi ħdejjem tat tirriema mhux għax mriex nibża' minr-rab-minn dak imma sa ħaw ma nafx kif bniedem jasal hemm
# dia_discuss_topic05_18f_12m_spk_0_84	435.02	437.08	irid ikun altru xi għax vera speċjali għalija biex inkun irila permanenti uġistr nej je bissa biex għra ħa badtu sbajlu ax għaddiltu meta ridt tis se tnaċċa gax-xar tista' taqta' tista' tiżbol imma ġismek qisek hamm ħafafeir sbieħ fid-dinja intikx rid inħobbo coċċh prinz hu hekk imma ma nimmaġinanix nagħżel oġġett li ningħid illa lià tant hu sabiħ li rridu perma lid tfuqi li fil-verità issa m' għandhiex m' għandhix il-ħqqija m' għandhiex hekk illum il-ġurnata ima sotaemm errapu bil-apparentement biex tneħħiha twoġġa' aktar milli biex tagħmilha eemm u anka u anka il-hem
# dia_discuss_topic05_18f_12m_spk_0_88	476.84	481.8	dak il-kreem jisultat anka meta tagħmiltatul ngħiduha kif inhi imma hhux hekk lejlet il-ħabiba tiegħi għandni ħa għandi mhux hekk kelli ħabiba tiegħi hemm tħobb tesperimenta hi stess bil-bin-need il h mhux bil-i magna orrajt hawne e bħalme żewġ tatllandiża eżat eżatt tobbt il-qħan awn qaml sbieħ fa qafisham vela ġelnitni dit tgħidli lua ħni lisħu speċi ka mbat semma ed dan ifhimni ħa ħa ħa ħa ħa imri keekoa gerix daqsejt permanenti morzi u ntini noħotizà bneħħija l-għalja imma int kif inti ivma tagħmel x koż sabiħ ta' ħafna jiġifieri h għax qiegħed tista' tpita ħawma e u tabirgħaxwoż sabiħ imma bil-dan in-nit huwa wn malta le le ġifir mant f' haw malta ma nafx nħassux imma ikk tgariex għax xrat eħdustoi lamażonna bdiet meta taniżmieri menda huma infisax li għandha koċċ ċelebazjonal-pass isti li għandu ma ji e mhuwiex fin daqs il- ġiep tal-oħra mmagna waranin m' għandix idea mhux fl-il-das il-mag naturali dażentenza il-uħm il-li il-il-il-linka għandha tenden trespandi iktar lik
# dia_discuss_topic05_18f_12m_spk_0_92	560.62	562.94	lart kal ħafna oħna
# dia_discuss_topic05_18f_12m_spk_0_94	564.12	564.66	ard laf żot
# dia_discuss_topic05_18f_12m_spk_1_5	11.68	13.187847314404472	'Ġifieri fuq di' ħa naqblu
# dia_discuss_topic05_18f_12m_spk_1_20	55.22	55.91169192510044	mhm
# dia_discuss_topic05_18f_12m_spk_1_26	65.7	74.90250447415424	Mhux hekk.
# dia_discuss_topic05_18f_12m_spk_1_33	83.88599677759527	87.99058846627445	'iġifieri jekk pereżempju jiena naċċetta li an...kwalunkwe
# dia_discuss_topic05_18f_12m_spk_1_37	97.94411187470342	98.61640147287646	Kristu ma...ma' spal...ma jdejh u ngħidlu   għax Kristu msallab ma' jdejh.
# dia_discuss_topic05_18f_12m_spk_1_39	103.06	104.78744355055385	Imma+ nara stramba [i]mbagħad qisha ah...
# dia_discuss_topic05_18f_12m_spk_1_46	134.24	135.34610027028296	jekk t...ħa tkun f'kuntest fejn nies ħa jarawha li huma jew minorenni jew qiegħda f'kuntest forsi pulit taf
# dia_discuss_topic05_18f_12m_spk_1_54	149.5874153150353	150.58416161482097	eżatt pereżempju+
# dia_discuss_topic05_18f_12m_spk_1_56	152.2557882217532	154.41966489068852	'eq
# dia_discuss_topic05_18f_12m_spk_1_63	174.6	176.74	jiġifieri imali ma fiha xejn ħażin bħala stampa
# dia_discuss_topic05_18f_12m_spk_1_65	178.14	187.94	m' għandix għalfejn pieni tiegħi m' għandhix titgħattha m' għandix a kieku m'għandux għalfejn jitkaża jew jew m' għandux għalfejn influwenza ruħu b' mod ħażin fuq fuq l-individwu
# dia_discuss_topic05_18f_12m_spk_1_69	211.44	224.9	qisek jaħk ti l-idea li la jkollok settur bla ma trid ħa tiġi iġġudikat għad hawn nies jaħsbu li hija xi ħaġa li ont le tagħmilha ma tistax titnaħħa li issa huwa argument skorrett ħafna minħabba l-fatt illum hawn lejn żep
# dia_discuss_topic05_18f_12m_spk_1_71	226.36	236.86	tredment uġieli kien hawn pereżempju n-nies kienu f'relazzjonijiet għamlu għamlu tatu tal-partner tagħhom li mbagħad ħassru ġennata kbira hu ħassru u e u dana
# dia_discuss_topic05_18f_12m_spk_1_73	238.1	254.92	illum jisħunaħuh ije sa-ġrejs tar naħseb għax in ġieli ngħid dħal l-iskar iva fil-fatti ġieli jagħmlu oħra fuqha emm jaktuha jagħmlu oħra fuqha mbagħad u ha min jikkoreġihom mill-ewwel direttament imma ovvjament irid rid tkun itik id-diżimpreċeventi biex tagħmel he
# dia_discuss_topic05_18f_12m_spk_1_77	260.76	265.7	siġa però għandi ħafna mill-bieb tiegħi għandhom tatus u għandi ħbieb li għandhom tatus
# dia_discuss_topic05_18f_12m_spk_1_79	268.58	273.2	enormi jiġifieri dak it-tip ħamsin sittin fil-mija ta' ġisimhu dak it-tip ek
# dia_discuss_topic05_18f_12m_spk_1_88	299.56	313.1	hekk hemm ċerta llukk kompluta li hija naqra intiminanti ma nafx x' inhiex ni inix għandix idea żbaljata imma jidhirli li hawn malta fil-kostituzzjoni ta'tuse fil-wiċċ ma jistax ikollok en diversi pace
# dia_discuss_topic05_18f_12m_spk_1_90	314.36	318.7	m' iniex ċert jiena smajt hawn waqtu waqt diskussjoni u
# dia_discuss_topic05_18f_12m_spk_1_92	320.76	344.74	ma kontx fiha d-diskussjoni għax kienet fuq ir-radiow jiġifieri u xi ħadd qħabda dal-kumment u għid dik l-impressjoni ma nafx jekk hux vera eħe li fil-wiċċ mhux suppost ikollok qatt ma rajt ataimma lejn arna-rajt rajt kemm-il darba jien forsi li jinħatana imma mamhux f' wiċċi biżifil-wiċċ li hewn fuq il-moħħ qegħdin ngħidu fuq il-wardiet rajt rinde iva imrajtu u jibqgħu niżlen
# dia_discuss_topic05_18f_12m_spk_1_94	346.26	356.4	issa nfhimni inti trid tqis inti trid tqis i hawn f' dail-pajjiż hawn ħafna li-liġijiet li mhumiex infurzati qed tifhem kapaċi dinja waħda minnhom
# dia_discuss_topic05_18f_12m_spk_1_96	357.96	384.8	hemm jien lanqas tikk i ma nafx sinċerament ma nafx x' inhija jekk teżisti verek jekk nerġa' ngħid m' iniex żbaljat ma nafx x' inhuwa il-il-il-kunċett warajha sinċerma għax fil-vetà binhemm li jkollu tatum iktar jintgħaraf ġo wiċċu ħe ħa ħa ħa ħa ħa jiġifieri ħi iktar jieu itar i le jiġiefi ma tistax taħttaħbil-wiċċ għax xi ħaġa din mhux maskina jew ħelmit dħalt biha
# dia_discuss_topic05_18f_12m_spk_1_98	386.18	389.1	xi minn post umgħarfek ħatt x e
# dia_discuss_topic05_18f_12m_spk_1_100	390.22	392.36	le wagħid tajb le ma m 'għinlhix iddeħera dika
# dia_discuss_topic05_18f_12m_spk_1_104	400.58	422.3	għandna ħafna nisa għandho tetuts jiġifieri kkumurissima jiġifieri kumpaniji kolla li l qadem gal-fammija akważi pti ta ditigħi komunissimli kollha tatuż imma eħe normamentux dik it-tip li hija adostrim sħiħa ehe hekk k va jkollhom dik it-tetuż żgħar pereżempju ma' saqajhom iħenaqra differenti lejra meta għaddejja kull sena ngħaddi mill-fażi ngħid irribtgħidtuko qatt ma qatt ma nagħmilha
# dia_discuss_topic05_18f_12m_spk_1_106	424.12	433.34	ħe-ħi ħdejjem tat tirriema mhux għax mriex nibża' minr-rab-minn dak imma sa ħaw ma nafx kif bniedem jasal hemm
# dia_discuss_topic05_18f_12m_spk_1_112	476.84	481.8	hawn il-xi x' tgħid il-folo appao jiġifieri biex tieħu ħsiebha wara għandek ħafna
# dia_discuss_topic05_18f_12m_spk_1_118	564.12	564.66	lart kal ħafna oħna
# dia_discuss_topic05_18f_12m_spk_1_120	566.76	567.76	ard laf żot
# dia_spont01_13m_14m.tsv
# {'Machine'}
# dia_spont01_13m_14m_spk_0_2	1.68	6.899788981043842	Baż bażikament
# dia_spont01_13m_14m_spk_0_3	6.899788981043842	8.64	t
# dia_spont01_13m_14m_spk_0_7	15.88	18.54	u u
# dia_spont01_13m_14m_spk_0_8	18.54	20.46	u speċi fil-bidu ma tantx konna ħbieb speċjalment ħabba
# dia_spont01_13m_14m_spk_0_9	20.46	21.94	'a
# dia_spont01_13m_14m_spk_0_10	21.94	27.3	l-aħmar u l-b ... l-aħdar
# dia_spont01_13m_14m_spk_0_12	28.84	30.5	ee ee
# dia_spont01_13m_14m_spk_0_13	30.5	32.34	kienet bla sens
# dia_spont01_13m_14m_spk_0_15	44.18	46.42	uu
# dia_spont01_13m_14m_spk_0_17	57.2	58.48	nofshom
# dia_spont01_13m_14m_spk_0_18	58.48	80.46	nofsu ħabba fih le mhux vera ħabba fija. Eżatt. Iva għidilna għidilna l-istorja ta' subgħajk
# dia_spont01_13m_14m_spk_0_20	82.06	93.22	u joħroġ dan
# dia_spont01_13m_14m_spk_0_34	121.9	123.28	miskin
# dia_spont01_13m_14m_spk_0_39	137.7	150.2	miskin
# dia_spont01_13m_14m_spk_0_44	170.48	171.74	anzi
# dia_spont01_13m_14m_spk_0_45	171.74	172.86	qallek qallek issa ieqaf idgħi u telaq 'l hemm jimxi. Ma+ le gravi kien dak   miskin
# dia_spont01_13m_14m_spk_0_47	174.86	192.96	imbagħad konna erfajnik sa sa ħdejn il-viċi
# dia_spont01_13m_14m_spk_0_48	192.96	194.44	miskin
# dia_spont01_13m_14m_spk_0_50	205.48	207.8	miskin
# dia_spont01_13m_14m_spk_0_53	215.48	218.34	mm
# dia_spont01_13m_14m_spk_0_54	218.34	234.88	Li kieku fqajt subgħajja ma kienx ikolli aptit niġi jiena wkoll
# dia_spont01_13m_14m_spk_0_60	253.42	254.54	?ja
# dia_spont01_13m_14m_spk_0_64	261.26	266.56	ija mela
# dia_spont01_13m_14m_spk_0_66	269.0	272.96	Jiena jiena ridt inkun hawn x'jgħidulu dak il-president tal-KFJC. Jiena min kien imissni &iġifieri kont numbrah daqshekk.
# dia_spont01_13m_14m_spk_0_70	288.34	290.7	omi m
# dia_spont01_13m_14m_spk_0_71	290.7	291.36	'a
# dia_spont01_13m_14m_spk_0_73	293.3	294.26	umbagħad issa speċi dħalna l-Università u
# dia_spont01_13m_14m_spk_0_74	294.26	295.44	u e
# dia_spont01_13m_14m_spk_0_76	298.2	300.72	imma
# dia_spont01_13m_14m_spk_0_77	300.72	312.02	imma anka
# dia_spont01_13m_14m_spk_0_78	312.02	313.5	'a ironikament
# dia_spont01_13m_14m_spk_0_80	313.76	315.64	'a
# dia_spont01_13m_14m_spk_0_81	315.64	318.66	kellna naqra qisu xi ħaġa lejn il-kitba ukoll. Konna ktibna artiklu flimkien fi żmien JC
# dia_spont01_13m_14m_spk_0_82	318.66	320.78	ee ?din
# dia_spont01_13m_14m_spk_0_83	320.78	325.06	Dik riżultat ta' pika kienet? Għala? Ija mela mela u l-oħrajn l-SDM riedu
# dia_spont01_13m_14m_spk_0_85	326.56	339.84	Iva. Ħa nikteb artiklu
# dia_spont01_13m_14m_spk_0_89	357.98	376.3	Vera? <laughter? Ma niftakarx ma niftakarx
# dia_spont01_13m_14m_spk_0_90	376.3	377.78	il-ostra
# dia_spont01_13m_14m_spk_0_91	377.78	382.0	'a. U mhux vera dik kienet timpika ma' kulħadd
# dia_spont01_13m_14m_spk_0_93	383.9	386.24	Urejtha &iġifieri urejtha
# dia_spont01_13m_14m_spk_0_94	386.24	387.38	'a ajma
# dia_spont01_13m_14m_spk_0_96	390.46	391.94	ajma
# dia_spont01_13m_14m_spk_0_97	391.94	408.34	Ija ħafna tad-daħk.
# dia_spont01_13m_14m_spk_0_99	410.94	413.84	Umbagħad speċi ħalli nkomplu l-istorja tagħna
# dia_spont01_13m_14m_spk_0_100	413.84	414.92	'a
# dia_spont01_13m_14m_spk_0_101	414.92	418.18	Covid qisu farrak lil kulħadd
# dia_spont01_13m_14m_spk_0_103	420.76	422.68	Konna qabel il-Covid &fej l-ewwel sena konna konna konna niltaqgħu ħafna hawnhekk hawn isfel fil- ... mhux hawn isfel l-iktar li konna niltaqgħu jiena u inti. Ee. Redent
# dia_spont01_13m_14m_spk_0_105	424.84	440.12	Le vera inti kellna ftit ... kellna xi waħda fil-ġimgħa &iġifieri ftit għax il-bqija kont inkun xogħol jien umbagħad
# dia_spont01_13m_14m_spk_0_109	450.78	453.42	inti [i]t-tort tiegħek
# dia_spont01_13m_14m_spk_0_111	454.9	456.94	u+
# dia_spont01_13m_14m_spk_0_112	456.94	458.48	U ija mbagħad bit-teżi tiegħi speċi kont iktar kont inkellmek fuq il-Malti u hekk. Kien jiġri xi ħaġa tad-daħk ta' ? ngħidlu ara x'kiteb
# dia_spont01_13m_14m_spk_0_113	458.48	459.7	umbagħad
# dia_spont01_13m_14m_spk_0_114	459.7	468.5	Tiftakar dik tal- tal-aċċenti? Dik kienet bis-sens. Dik kienet bis-sens
# dia_spont01_13m_14m_spk_0_115	468.5	471.16	's
# dia_spont01_13m_14m_spk_0_116	471.16	476.18	Imma hemm wisq xi ngħidu fuq xulxin biex
# dia_spont01_13m_14m_spk_0_117	476.18	477.72	dan
# dia_spont01_13m_14m_spk_0_118	477.72	480.26	għax kieku &aqas nieqfu
# dia_spont01_13m_14m_spk_0_119	480.26	482.0	Iva
# dia_spont01_13m_14m_spk_0_120	482.0	484.5	iva nistgħu niktbu ktieb vera.
# dia_spont01_13m_14m_spk_0_121	485.84	487.24	ee
# dia_spont02_13m_14m.tsv
# {'Machine'}
# dia_spont02_13m_14m_spk_0_0	138.83447185391614	139.9745469189471	għedna uu
# dia_spont02_13m_14m_spk_0_3	142.24	143.50419997468958	ee
# dia_spont02_13m_14m_spk_0_6	144.96493529689158	146.70391184402533	Le le qaltilna... qaltilna oqogħdu haw'
# dia_spont02_13m_14m_spk_0_7	146.70391184402533	149.22890014942115	ħa nġib
# dia_spont02_13m_14m_spk_0_8	149.22890014942115	150.19785457981516	il-prinċipal.
# dia_spont02_13m_14m_spk_0_10	151.24	152.78173997390797	Telqet għall-prinċipal u tlaqna niġru.
# dia_spont02_13m_14m_spk_0_12	154.45139005271324	158.56139286090038	Ija issa naħseb stejjer oħra wisq
# dia_spont02_13m_14m_spk_0_13	158.56139286090038	160.8663458409113	kriminali biex ngħiduhom.
# dia_spont02_13m_14m_spk_0_23	177.6854684458458	179.95958026864466	Eżatt eża...
# dia_spont02_13m_14m_spk_0_30	193.99610863417325	195.27159401388857	Iv... le mhux xi kultant naħseb iktar
# dia_spont02_13m_14m_spk_0_31	195.27159401388857	197.4821734681542	iktar bil-kontra
# dia_spont02_13m_14m_spk_0_32	197.4821734681542	198.685079388005	xi kultant mhux mingħajr vodka.
# dia_spont02_13m_14m_spk_0_33	198.685079388005	200.33455148213415	Ajma
# dia_spont02_13m_14m_spk_0_35	202.41668391103315	206.07409284799223	Le le
# dia_spont02_13m_14m_spk_0_37	206.83877817118238	207.55292235285674	ma konniex
# dia_spont02_13m_14m_spk_0_38	207.55292235285674	208.68255766869294	&qax xejn.
# dia_spont02_13m_14m_spk_0_40	209.82680033775114	210.88	Ee x'hemm iktar tad-daħq?
# dia_spont02_13m_14m_spk_0_42	212.49925483323068	215.5675005235682	Taz-zalzett taz-zalzett.
# dia_spont02_13m_14m_spk_0_43	215.5675005235682	217.5297549730595	Mela jien kont hemm
# dia_spont02_13m_14m_spk_0_44	217.5297549730595	219.49386975622335	jien kont... mela mela
# dia_spont02_13m_14m_spk_0_50	228.4108612047274	230.60034806182577	speċi
# dia_spont02_13m_14m_spk_0_51	230.60034806182577	231.9783083824363	ma nafx jekk għadhiex hekk bħalissa imma
# dia_spont02_13m_14m_spk_0_56	239.26233722407412	240.2973755008239	U qabadna l-ġuħ
# dia_spont02_13m_14m_spk_0_57	240.2973755008239	241.5297299650232	u għedna uwija ejja mmorru &nixxu
# dia_spont02_13m_14m_spk_0_58	241.5297299650232	243.00994175818786	&qas... &qas jiena le le
# dia_spont02_13m_14m_spk_0_59	243.00994175818786	244.4025094320204	mar wieħed minna konna erbgħa
# dia_spont02_13m_14m_spk_0_60	244.4025094320204	246.91799333983937	u mar wieħed minna.
# dia_spont02_13m_14m_spk_0_61	246.91799333983937	248.27833752315968	U *t-tlieta oħra jin... jin... inkluż jiena 'iġifieri
# dia_spont02_13m_14m_spk_0_62	248.27833752315968	251.20120082542712	tlaqna niġru warajh.
# dia_spont02_13m_14m_spk_0_68	259.6303555178095	262.57247182269845	ieħor minn dawn it-tlieta biex niftehmu
# dia_spont02_13m_14m_spk_0_69	262.57247182269845	264.3643071512663	ħaduhielu u tlaqna niġru iktar.
# dia_spont02_13m_14m_spk_0_73	269.37533082013266	272.37053974436014	kappella.
# dia_spont02_13m_14m_spk_0_76	273.9537045237923	275.31845014904434	naqra spazjuż.
# dia_spont02_13m_14m_spk_0_78	276.85709135509717	277.797298754856	U+ dħalna niġru ġod... ġod... di... da...
# dia_spont02_13m_14m_spk_0_80	280.48065030577595	281.67358415224095	Kien hemm erbgħa
# dia_spont02_13m_14m_spk_0_82	282.7589401021653	283.70354894385594	Jiena
# dia_spont02_13m_14m_spk_0_86	288.15833437032643	290.8233682702427	T... t...
# dia_spont02_13m_14m_spk_0_88	292.32491686804246	293.3230860048805	Le ta' Kyle kien.
# dia_spont02_13m_14m_spk_0_89	293.3230860048805	294.7794198851508	Ta' Kyle kien.
# dia_spont02_13m_14m_spk_0_91	296.2645007960562	297.1724847053026	Ee ħeqq mela iva tiegħu kien.
# dia_spont02_13m_14m_spk_0_92	297.1724847053026	299.22725239186684	Mela mela jiena
# dia_spont02_13m_14m_spk_0_96	304.7374775481044	305.48176141827724	Imbagħad daħal ieħor warajna
# dia_spont02_13m_14m_spk_0_98	307.4050629258433	309.8646688985966	u qagħad jgħodd.
# dia_spont02_13m_14m_spk_0_105	323.7277693591334	325.79227528117895	ġUħmbagħad f'daqqa waħda
# dia_spont02_13m_14m_spk_0_106	325.79227528117895	327.75986652421994	qagħad kwiet
# dia_spont02_13m_14m_spk_0_109	331.3576872283319	333.41755787054115	oqogħdu kwieti.
# dia_spont02_13m_14m_spk_0_110	333.41755787054115	334.2409064445239	U nisimgħu
# dia_spont02_13m_14m_spk_0_112	335.3072432297314	336.3580476796622	X'qed tagħmlu hemm intom? X'qed tagħmlu hemm?
# dia_spont02_13m_14m_spk_0_114	338.09794920885054	338.69013160910345	U aħna
# dia_task_maptask01_13f_10m.tsv
# {'Spk 1 Machine', 'Spk 2 Machine'}
# dia_task_maptask01_13f_10m_spk_0_2	4.441266112474453	5.0872684561070995	sieb il-knisja ta' santa rita
# dia_task_maptask01_13f_10m_spk_0_4	6.84358732785836	8.599906199609622	inżel 'l isfel fuq il-issa jien skont il-qed iħares lejha hekk mela din tiġi fuq il-lemin
# dia_task_maptask01_13f_10m_spk_0_6	14.35336457258789	20.793200435675846	ibqa' nieżel
# dia_task_maptask01_13f_10m_spk_0_8	22.145767842656703	22.731207466573785	aqbeż tliet postijiet milli għandek tlieta
# dia_task_maptask01_13f_10m_spk_0_10	24.50771391156357	27.919413788873488	u itla' 'l fuq jiġifieri inti fil-karta supp-għall-inqas tiegħi għandi tliet postijiet u ddaħa ndurru magħhom u bqajna ti l-għajn 'il fuq
# dia_task_maptask01_13f_10m_spk_0_12	30.786049188743362	39.44651810806854	jekk għandek eh ieqaf ħdejn tax-xwiereb
# dia_task_maptask01_13f_10m_spk_0_14	43.66572091491927	47.72342313586184	akkademja mużikali
# dia_task_maptask01_13f_10m_spk_0_16	51.15531058641029	52.02337623566665	jekk għandek ħu
# dia_task_maptask01_13f_10m_spk_0_18	55.17263766087581	56.383892055187026	għaddi minn magħha u ibqa' tiela' 'l fuq
# dia_task_maptask01_13f_10m_spk_0_20	59.149589588864295	61.2490972056704	aqbad it-triq tal-lemin erġa' u aqbeż tliet oġġetti milli għandek
# dia_task_maptask01_13f_10m_spk_0_22	67.34574432370351	72.37245006009505	inżel waħda 'l isfel
# dia_task_maptask01_13f_10m_spk_0_24	79.49866341329269	80.95216868646615	u dur ma' post wieħed
# dia_task_maptask01_13f_10m_spk_0_26	82.08267278782327	84.82818274826205	tista' ħuiiitipprova ħu ħu
# dia_task_maptask01_13f_10m_spk_0_29	89.77413819169949	90.9853925860107	dur miegħu u itla' 'l fuq
# dia_task_maptask01_13f_10m_spk_0_31	92.60039844509232	94.47784275627471	ibqa' tiela' dejjem 'il fuq
# dia_task_maptask01_13f_10m_spk_0_33	99.72661179828997	100.81674075317007	jiena wasalt għal-ħruġ inti x'għamilt eġefen a ruchavin eħe ħruġ mela dħul u ħruġ
# dia_task_maptask01_13f_10m_spk_0_35	104.20825305724146	110.64808892032943	ħa nara issa
# dia_task_maptask01_13f_10m_spk_0_38	113.21191072162149	118.13767859182045	bejn wieħed u ieħr għox ħe
# dia_task_maptask01_13f_10m_spk_0_40	120.43906194101172	121.2061897240755	ħi ħi ħalla itra dan u
# dia_task_maptask01_13f_10m_spk_0_42	122.2963186789556	124.55732688166987	le għax kien hekk bdajt kif jien għidtlek inżel 'l isfel mhux minn hemm inti mhux midħult il-knisja ta' santa rita tih fejn qedha allura kif bdejt minn hemm fuq
# dia_task_maptask01_13f_10m_spk_0_44	127.78733859983309	139.31444291902818	għidtlet qsieb il-il-knisja ta' santa rita qed tara kemm jisma' minni dan eħe
# dia_task_maptask01_13f_10m_spk_0_46	142.66558007662252	148.1364124242615	u baqa' miexji għal isfel qeisfer rużal fl-iżvelot eħe ibqa' miexjek eħe eħe ibqa' tielha' 'l fuq tibqa' tiela' 'l fuq tajjeb mont tax-xwiereb eħe u bqaħthilha 'l fuq tu tajjeb dak il-lajn eħe dur mau erġajt lajt 'l fuq orrajt mela dak il-lajm minn hemmhekk gal ġlik kif ġie
# dia_task_maptask01_13f_10m_spk_0_48	149.20635380590306	169.21223888527663	sħi ħi ħi ħi i i i i i
# dia_task_maptask01_13f_10m_spk_0_50	171.2915589288442	173.2699411062192	inti din di kif bdejt minn hawn u ġej qam għandek dan l-għajnekk qed tarah dak il-lgħajn inti m' għandekx
# dia_task_maptask01_13f_10m_spk_0_52	174.80419667234673	181.93041002554438	jekk u
# dia_task_maptask01_13f_10m_spk_0_56	184.95854601132243	186.91674061545888	qgħidtlek ħsieb il-knisja ta' santa rita fejn il-knisja auwiu ba orġe bħħd tara kemm jisma' minni dak
# dia_task_maptask01_13f_10m_spk_0_59	194.57988725429212	196.2030243051782	qed tara kieku smajt minni tajba ħafna ru mill-qawl mhux minn hemm intin mhux minn hemm trid qed tibda bid-dħul għidtlek il-qsib il-knisja ta' santa rita u trid tibda minn hemm jiġifirint qied jinżel 'l isfel eenżel 'l isfel hmelanibda minn iżra santa rita għidtli ħsibha
# dia_task_maptask01_13f_10m_spk_1_4	138.15048276885344	140.9773267748184	Allura kif bdejt minn hemm fuq?
# dia_task_maptask01_13f_10m_spk_1_8	145.84684472141635	146.48017476839735	Qed tara kemm jisma' minni da'?
# dia_task_maptask01_13f_10m_spk_1_10	149.10300779092827	151.11380306693405	Ehe u u ibqa' miexja 'l isfel
# dia_task_maptask01_13f_10m_spk_1_16	159.85878828498463	160.5614821622577	u ibqa' tiela' 'l fuq tif... tajjeb
# dia_task_maptask01_13f_10m_spk_1_34	180.47269519052	181.51647255365629	M'għandekx
# dia_task_maptask01_13f_10m_spk_1_36	182.10555804534772	183.00537914809388	jekk
# dia_task_maptask01_13f_10m_spk_1_38	185.30561773469856	186.24012075259077	mel' inti ħruġ bdejna l-ewwel id-dħul
# dia_task_maptask01_13f_10m_spk_1_40	189.55022018209505	191.27680074730796	Għidtlek sib il-knisja ta' Santa Rita. Fejn hi l-knisja?
# dia_task_maptask01_13f_10m_spk_1_44	194.55808309182237	195.47562784959624	Tara kemm jisma' minni dak.
# dia_task_maptask01_13f_10m_spk_1_54	208.05693521905678	210.0556181372956	u t'id tibda minn hemm.
# dia_task_maptask01_13f_10m_spk_1_56	211.84276528756627	213.27486038314296	Ee inżel 'l isfel mhux iż...
# dia_task_maptask01_20f_13m.tsv
# {'Machine'}
# dia_task_maptask01_20f_13m_spk_0_2	5.1	7.64	issa jien għandi l-kappella ta' santa rita istes ħaġa naħseba dik hi dik hi qed tara l-iskola tal-kinder
# dia_task_maptask01_20f_13m_spk_0_4	8.86	15.22	l-iskola tal-kinder
# dia_task_maptask01_20f_13m_spk_0_7	18.02	19.66	le le maienara l-iskola il-bank internazzjonali il-bank lokali dak hu naħseb ta ma naħsibx li hemm il-bank lokali għandi fejn jagħtiha li qiegħed on te
# dia_task_maptask01_20f_13m_spk_0_9	21.02	35.52	qiegħed fuq il-lemin fuq il-lemin ftit 'il fuqi see mal-ebda imxi 'l hemm sewwa
# dia_task_maptask01_20f_13m_spk_0_11	38.36	43.88	hemm iqqa' mhix iktar
# dia_task_maptask01_20f_13m_spk_0_13	45.48	46.84	lejn il-lemin qed tarah il-ġnien il-kbir hemm ġnien nien il-kbir uwa inm' mxi miegħu
# dia_task_maptask01_20f_13m_spk_0_15	48.18	52.76	u għandek tara ħanuta ħwejjeġ u pompa tal-petroll iva iktar titla' bejniethom eżatt titla' bejniethom
# dia_task_maptask01_20f_13m_spk_0_17	54.26	60.52	sewwa saċettara inti
# dia_task_maptask01_20f_13m_spk_0_19	62.0	63.58	bejniethom hemm aġenzija tal-proprjetà iktar 'il fuq tar 'il fuq qegħda ħdejn il-knisja ta' santa marija
# dia_task_maptask01_20f_13m_spk_0_21	65.78	71.1	iktar 'l isfel imma iktar 'l isfel tridt titla' ik tara sewwa mal-aqba' miexja lejn il-knisja ta' santa marija sewwa u ħdejha hemm il-kunsill lokali suppost hekk hu iva qed tara l-knisja hawn l skużani siġra fil-kantuniera
# dia_task_maptask01_20f_13m_spk_0_23	72.52	85.7	is-siġra fil-kantuniera le ta jew ħed nara semm hemm bard bil-bar tax-xwiereb
# dia_task_maptask01_20f_13m_spk_0_25	87.5	92.48	tax-xwiereb qiegħed fuq in-naħa l-oħra eżatt imxi lejh u trid timxi lejh sewwa bat bla 'l fuq han kin trid taraha spiżerija 'l hemm
# dia_task_maptask01_20f_13m_spk_0_27	94.14	102.12	l-ispiżerija qiegħda ek tar lejn ix-xellug meta nitla' 'l fuqem l-istatwa tar-re ġorġ
# dia_task_maptask01_20f_13m_spk_0_29	104.62	109.38	mela ħadna rotta naħseb ħażina
# dia_task_maptask01_20f_13m_spk_0_31	114.22	116.66	mela tax-xwiereb hemm tnejn għax hemm bar u hemm għandek raġun iva għandek raġun orrajt mela hemm hemm il-bar issa arawh dak m' hemmhek iva u meta titla' minn fuqu e meta emmilha lizeri emm l-ispiżeri imbagħad għandek timxi fuq il-lemin hekk hemm dar vjola
# dia_task_maptask01_20f_13m_spk_0_33	118.26	136.98	ħamra ħamra ara jiena iva hawnhekk vjola tidher ifhem issa trid tmur għall-ħanut tax-xwiereb u ddur mama' dik il-blokk
# dia_task_maptask01_20f_13m_spk_0_35	138.36	146.94	u imxi fuq ix-xellug u mbagħad itla' naqa al fuq
# dia_task_maptask01_20f_13m_spk_0_37	148.28	150.6	sewwa jiġifieri mill-ispiżerija rrid immur mlesrle l-tar dar il-vjola i-ħamra li daqli
# dia_task_maptask01_20f_13m_spk_0_40	159.9	161.3	fuq il-lemin hekk hu sewwa meda hemm tax-xwiereb trid iddur miegħu tax-xwiereb irid ninżel naqra 'l frid inse na 'l isfel u ddur miegħu orrajt u titla' 'l fuq u mbagħad mhux
# dia_task_maptask01_20f_13m_spk_0_42	162.42	173.08	'il fuq 'il fuq trid tmur
# dia_task_maptask01_20f_13m_spk_0_44	174.62	176.02	eh xellug 'il fuq xellug 'l fuq orrajt sewwa wasalna tajjeb owkej ni
# dia_task_mmap03_13f_10m.tsv
# {'Spk 1 Machine', 'Spk 2 Machine'}
# dia_task_mmap03_13f_10m_spk_0_2	0.7459468656924784	2.127197447412506	X'tip ta' edukazzjoni taħseb li għandu jkun meħtieġ biex wieħed jibda jaħdem f'dawn l-oqsma?
# dia_task_mmap03_13f_10m_spk_0_6	7.946564652364097	8.988163451693953	Imma.
# dia_task_mmap03_13f_10m_spk_0_8	20.287246079206973	21.37413178285552	Trid tkun taf xi lingwi żgur għax ma tafx min ħa jiġi quddiemek.
# dia_task_mmap03_13f_10m_spk_0_10	22.732738912416202	25.993396023361843	Eħe eħe eħe.
# dia_task_mmap03_13f_10m_spk_0_13	43.71185713615856	49.60867753893558	Trid tkun qed iżżomm ruħek aġġornat. Tr...irid ikollok edukazzjoni tajba żgur.
# dia_task_mmap03_13f_10m_spk_0_17	61.47208778759065	70.39360793837251	Taġġurnata.
# dia_task_mmap03_13f_10m_spk_0_19	71.51509634793862	72.76048621670259	Ee. Mekkanik.
# dia_task_mmap03_13f_10m_spk_0_21	73.62093739875769	74.888970719681	Mhm.
# dia_task_mmap03_13f_10m_spk_0_27	103.33211958660947	107.11357609722006	Għalhekk hu xorta jrid ikollhom
# dia_task_mmap03_13f_10m_spk_0_29	112.65303566792784	114.78152017090625	Ee. Kif qed ngħdidu em. Iżommu ruħhom aġġaornati. Illum il-karozzi jinbidlu. Il-mekkaniżmu tagħhom jinbidel.
# dia_task_mmap03_13f_10m_spk_0_31	122.39473850065296	130.50006643956564	Em.
# dia_task_mmap03_13f_10m_spk_0_33	131.30365200768918	133.13777163259613	Irid ikollhom. Xorta jrid ikollhom naq'a edukazzjoni għolja.
# dia_task_mmap03_13f_10m_spk_0_35	144.60037682943147	147.5656411281729	U trid tkun taf titkellem bl-Ingliż.
# dia_task_mmap03_13f_10m_spk_0_39	155.8078577141744	157.5287600782846	Bħalma kienet tgħid oħti. Kienet tgħid illum lanqas kważi għamilt lezzjoni. Iżje' kelli problemi tal-qalb milli problemi tal-edukazzjoni.
# dia_task_mmap03_13f_10m_spk_0_41	235.17661318776015	242.60366549602526	Imbagħad ikunu tfajliet fi skola sekondarja.
# dia_task_mmap03_13f_10m_spk_0_45	248.26092692221206	250.83661960533755	Tal-familja
# dia_task_mmap03_13f_10m_spk_0_47	251.58642642282302	252.51480796135624	Kaxxiera.
# dia_task_mmap03_13f_10m_spk_0_51	258.44938615719644	259.6947760259605	Jien naf x'jiġifieri wkoll għax kont sitt xhur kaxxier il-bank  .
# dia_task_mmap03_13f_10m_spk_0_53	311.0034855434166	315.8403712027152	Tiħħendilja kollox u tridu
# dia_task_mmap03_13f_10m_spk_0_55	316.6660848667512	318.9304300826858	U l-istess+ ee tipi ta' nies li tiltaqa' magħhom
# dia_task_mmap03_13f_10m_spk_0_61	326.54169720025317	328.36449509908056	Irid ikollok edukazzjoni+ taf ċertu lingwi wkoll.
# dia_task_mmap03_13f_10m_spk_0_63	329.0236638349798	332.4994337414395	Għall-inqas a...aħna haw' malta ee Malti Ingliż Taljan &umbagħad m...
# dia_task_mmap03_13f_10m_spk_0_65	332.93493402561677	338.23350183090383	Jiġik xi ħadd forsi jifhem il-ġermaniż tgħajjat lil xi ħaddieħor. Skont il-lingwa+ ee li tiġi quddiemek &umbagħad.
# dia_task_mmap03_13f_10m_spk_0_67	338.72561074547946	345.05445562401684	Bennej jew bennejja.
# dia_task_mmap03_13f_10m_spk_0_69	346.95599071221505	348.46178028081164	Qatt ma rajt bennejja mara s'issa.
# dia_task_mmap03_13f_10m_spk_0_71	349.42611113874915	352.24998235326126	U jista' jkun ukoll li jkun haw'.
# dia_task_mmap03_13f_10m_spk_0_73	352.74813830076687	354.5369710213551	Mhm.
# dia_task_mmap03_13f_10m_spk_0_75	366.54855144128794	367.40900262334304	Irid iko...irid ikollok bilfors.
# dia_task_mmap03_13f_10m_spk_0_77	381.7291872293963	384.3105407755616	Eħe anki ċertu+ affarijiet jien nar'a minna bnejna l-posta tagħn...bdejna l-blokka tagħna
# dia_task_mmap03_13f_10m_spk_0_79	405.09466002250826	411.9782694789491	Kont immur kuljum+ u 'ekk narah jara qed jara l-pjanta nar'a miegħu ġieli. Ġieli tiġbdilhom l-attenzjoni int tispiċċa ċertu affarijiet.
# dia_task_mmap03_13f_10m_spk_0_81	412.499068878614	420.0217133997234	Iħalluhom barra jibqgħu għaddejjin.
# dia_task_mmap03_13f_10m_spk_0_83	420.6280682038188	422.3942574722477	Ikollok xi ħaġa iħallilek xi tieqa ma jagħmilhiex.
# dia_task_mmap03_13f_10m_spk_0_85	423.3326758191946	425.8687424610412	Bħalma għamel tagħna.
# dia_task_mmap03_13f_10m_spk_0_87	426.3442549563875	427.9745835118603	Imma insomma. Kollox il...il...kif qed ngħidu biex tkun taf taqra+ [i]l-pjanta jrid ikollok ed...edukazzjoni  biex tara x'inhi.
# dia_task_mmap03_13f_10m_spk_1_2	0.7459468656924784	2.127197447412506	Ngħaddu għal xa& ħaġ'oħra.
# dia_task_mmap03_13f_10m_spk_1_4	2.3989188733246425	7.312547991902445	X'tip ta' edukazzjoni taħseb li għandu jkun meħtieġ biex wieħed jibda jaħdem f'dawn l-oqsma?
# dia_task_mmap03_13f_10m_spk_1_8	20.287246079206973	21.37413178285552	Imma.
# dia_task_mmap03_13f_10m_spk_1_10	22.732738912416202	25.993396023361843	Trid tkun taf xi lingwi żgur għax ma tafx min ħa jiġi quddiemek.
# dia_task_mmap03_13f_10m_spk_1_12	39.46470815697294	43.71185713615856	Eħe eħe eħe.
# dia_task_mmap03_13f_10m_spk_1_15	50.87671085985889	55.08839296149703	Trid tkun qed iżżomm ruħek aġġornat. Tr...irid ikollok edukazzjoni tajba żgur.
# dia_task_mmap03_13f_10m_spk_1_19	71.51509634793862	72.76048621670259	Taġġurnata.
# dia_task_mmap03_13f_10m_spk_1_21	73.62093739875769	74.888970719681	Ee. Mekkanik.
# dia_task_mmap03_13f_10m_spk_1_23	86.07116473405614	87.04	Mhm.
# dia_task_mmap03_13f_10m_spk_1_29	112.65303566792784	114.78152017090625	Għalhekk hu xorta jrid ikollhom
# dia_task_mmap03_13f_10m_spk_1_31	122.39473850065296	130.50006643956564	Ee. Kif qed ngħdidu em. Iżommu ruħhom aġġaornati. Illum il-karozzi jinbidlu. Il-mekkaniżmu tagħhom jinbidel.
# dia_task_mmap03_13f_10m_spk_1_33	131.30365200768918	133.13777163259613	Em.
# dia_task_mmap03_13f_10m_spk_1_43	315.06	316.2841696965072	U inti kont il-bank 'iġifieri
# dia_task_mmap03_13f_10m_spk_1_45	322.0016413667421	332.6179256953859	'Iġifieri+ dika iżjed problema għax għandek il-flus tan-nies u hekk hu
# dia_task_mmap03_13f_10m_spk_1_47	334.1463587161418	339.12	Eħe. Dik li hemm.
# dia_task_mmap03_13f_10m_spk_1_49	344.84	346.95599071221505	jiġik xi ħadd forsi jifhem ill-ġermani jiż ta jgħid lil xi ħaddieħor skont il-lingwa li tiġi quddiemeku mbagħad
# dia_task_mmap03_13f_10m_spk_1_51	348.2	350.46770993807905	Bennej.
# dia_task_mmap03_13f_10m_spk_1_67	404.2644405321513	404.8908689530741	Naħseb li għandu jkun ee li tagħmilhom l-eżamijiet u għall-inqas issib u a...b'dawk li tkun tara fejn f'liema livell wasalt għall-inqas.
# dia_task_mmap03_13f_10m_spk_1_73	420.6330866080257	422.67601570657365	Iva iva.
# dia_task_mmap03_13f_10m_spk_1_79	432.0051179962237	436.46485013748185	Imma insomma ma...
# dia_task_mmap03_13f_10m_spk_1_81	446.3323768747494	448.2524694041986	D...daw' il...ix...ix-xogħlijiet kollha li għandna mikutbin huma l-edukazzjoni hi...hija bżonnjuża jien ngħid f'kwalunkwa xogħol. Illum a'ka+
# dia_task_pics02_13f_10m.tsv
# {'Spk 1 Machine', 'Spk 2 Machine'}
# dia_task_pics02_13f_10m_spk_0_2	4.44	6.86	l-ewwel wieħed ir-raġel
# dia_task_pics02_13f_10m_spk_0_4	11.11769012143657	12.88355682205405	donnhu ħiereġ minn xi
# dia_task_pics02_13f_10m_spk_0_6	14.8	15.52	kampus tal-università nimmaġinah hekk
# dia_task_pics02_13f_10m_spk_0_8	18.28	19.94	ned narah li pereżempju forsi tard tax-xogħol sejjer
# dia_task_pics02_13f_10m_spk_0_10	22.48	25.92	jgħaġġel qed iżomm il-ġlek biex jgħaġġelu hekk il-passi
# dia_task_pics02_13f_10m_spk_0_12	27.88	31.6	jista' jkun kif qed tgħid intemm dak it-taraġ e
# dia_task_pics02_13f_10m_spk_0_14	34.94	37.46	ma nsomma dak nieżel minn xi mkien forsi bini għoli jew xi ħaġa għandu
# dia_task_pics02_13f_10m_spk_0_16	38.76	43.2	it-taraġ narah qed jgħaġġel
# dia_task_pics02_13f_10m_spk_0_18	44.82	46.94	tard tax-xogħol ħa nebdewh l-ewwel impressjoni tiegħi li ħadtha
# dia_task_pics02_13f_10m_spk_0_20	49.08	52.46	jidhir li qed jaħġġe ħħma nżomm ħu
# dia_task_pics02_13f_10m_spk_0_22	53.68	57.28	seta' kien qisu f' poża ta' xi jgħamil jista' jkun ukoll iva iva għandek ħaxhew affarijiet fil-bwiet a eħe eħelli ma jagħtux lok li huwa qad jagħmel modelling żgur għax għandu l-mmobilout din-naħa u l-oħrajn naħa l-oħra għandu xi ħaġa oħra jiġifieri mhux daqshekk e
# dia_task_pics02_13f_10m_spk_0_24	59.5	78.36	mhux daqshekk eleganti li għamel l monderlinge ħaanagħmlu hekk xi isuta għal kuljum li forsi rrid immur biha għax-xogħol jew hekk
# dia_task_pics02_13f_10m_spk_0_26	81.18	88.54	tieni it-tieni pikċer tieni stampa dawn sejrin
# dia_task_pics02_13f_10m_spk_0_28	90.54	95.34	danadonnha għandha sissistrument tal-mużika i ħa tieħu l-ql-omm ħatuħ u l-binta għal e qegħdin jagħġu għal i-xi lezzjoni wkoll jiġifieri tard forsi l-istess jew għaddejja xi protesta il-pulizia hemm il-pulizija u warajha ma tantx huma libsin ġus protesta ma' rajjiet puliż jess ħe
# dia_task_pics02_13f_10m_spk_0_30	97.1	118.64	e bil-ħel bil-krisħel eħe imma dawn it-tnejn l omm u t-tifla jieninzertaw għaddejjin minn quddiemhom eħa ma qegħdin jgħaġġlu kollox sar il-ħin għal-lezzjoni li jaqbad
# dia_task_pics02_13f_10m_spk_0_32	119.88	132.92	e jiġbed l-attenzjoni ikun hemm il-ġurnalisti a quddiem il-pulizija a ħa
# dia_task_pics02_13f_10m_spk_0_34	134.54	140.78	u t-tielet waħda ovvjament l-istampa qed tiġri għal xi maratona han dan-numru fuq fuq tix-il-ġerżi tagħha u l-teasheirt bomda qiegħda fiha ambjent e fil-beltani ui jidlu s-siġġar wara
# dia_task_pics02_13f_10m_spk_0_36	142.4	158.18	qegħdin jiġru fl-istess ħin mhix isase just joging eħe m' jidhix li xi ġirja imma insomm għanda l-wann fuq il-in-numru li wieħed tnejn zero jiġifieri i eqq a meta tmur tagħmel joging waħdek m' għandek bżonn in-numru aj min jiġifieri inmmaġinali xi tellieqa forsi ħqed jgħixu en t' hawn
# dia_task_pics02_13f_10m_spk_0_38	161.42	186.8	um għaddejja bret ma' imgħaġġel u
# dia_task_pics02_13f_10m_spk_0_40	189.16	191.2	x'tip ta' ħajja timmaġina li jgħixu n-nies f'dawn l-istampi dana għandu xi xogħol hekkħa neħduh bħal elisejjer għax-xogħol li jrid ikun dejjem pulit e bis-sut u hekk mhux għandhom xi drescod fieri tal-uffiċċju biex mhux jaqbad u jilbes l-affarijiet li jrid u jmexxi
# dia_task_pics02_13f_10m_spk_0_42	193.64	215.38	jew forsi xi lecċurere tal-universàta u jista' jkun ukoll donnhum ma do insomma ma nistgħux ngħidu hekk hux żgħir ħafna jew kbir ħa ħa
# dia_task_pics02_13f_10m_spk_0_44	216.64	226.34	e l-oħrajn qegħdin għaddejjin ma ma tantx huwa żmien sabiħ
# dia_task_pics02_13f_10m_spk_0_46	227.48	233.68	imma serjenarze ija imma xorta gall-ambjent ta' fejn qegħdin mhuwiex daqshekk żgur e pjaċevoli tara dawk is-suldati libsinekk istampa tal-ordarna irlandi ma nafx ma nistax nqlaq għas-s ilt-kliem hemmhekk u l-oħra bħa speċi
# dia_task_pics02_13f_10m_spk_0_48	234.92	252.84	dejjem għed themmiq t' ammira għal xi għax għandha asperazzjoni li forsi xi darba tkun tirbaħ
# dia_task_pics02_13f_10m_spk_0_50	254.78	262.02	'il xi tellieqa jew hekk
# dia_task_pics02_13f_10m_spk_1_2	0.2887722661793727	3.846474295364591	X'tista' tkun ir-raġuni li n-nies f'dawn l-istampi qed jiġru?
# dia_task_pics02_13f_10m_spk_1_4	7.508050836350837	10.15685088727706	Mħq l-ewwel wieħed ir-raġel
# dia_task_pics02_13f_10m_spk_1_8	16.623039246891068	17.428066713349036	kampus tal-università? Ħa nimmaġinah hekk.
# dia_task_pics02_13f_10m_spk_1_11	22.05791005689032	27.88	Mm mm.
# dia_task_pics02_13f_10m_spk_1_15	36.63623233580131	37.60171007808882	Eħe eħe eħe.
# dia_task_pics02_13f_10m_spk_1_17	53.68	57.28	jidhir li qed jaħġġe ħħma nżomm ħu
# dia_task_pics02_13f_10m_spk_1_19	59.5	78.36	seta' kien qisu f' poża ta' xi jgħamil jista' jkun ukoll iva iva għandek ħaxhew affarijiet fil-bwiet a eħe eħelli ma jagħtux lok li huwa qad jagħmel modelling żgur għax għandu l-mmobilout din-naħa u l-oħrajn naħa l-oħra għandu xi ħaġa oħra jiġifieri mhux daqshekk e
# dia_task_pics02_13f_10m_spk_1_21	81.18	88.54	mhux daqshekk eleganti li għamel l monderlinge ħaanagħmlu hekk xi isuta għal kuljum li forsi rrid immur biha għax-xogħol jew hekk
# dia_task_pics02_13f_10m_spk_1_23	90.54	95.34	tieni it-tieni pikċer tieni stampa dawn sejrin
# dia_task_pics02_13f_10m_spk_1_25	97.1	118.64	danadonnha għandha sissistrument tal-mużika i ħa tieħu l-ql-omm ħatuħ u l-binta għal e qegħdin jagħġu għal i-xi lezzjoni wkoll jiġifieri tard forsi l-istess jew għaddejja xi protesta il-pulizia hemm il-pulizija u warajha ma tantx huma libsin ġus protesta ma' rajjiet puliż jess ħe
# dia_task_pics02_13f_10m_spk_1_27	119.88	132.92	e bil-ħel bil-krisħel eħe imma dawn it-tnejn l omm u t-tifla jieninzertaw għaddejjin minn quddiemhom eħa ma qegħdin jgħaġġlu kollox sar il-ħin għal-lezzjoni li jaqbad
# dia_task_pics02_13f_10m_spk_1_29	134.54	140.78	e jiġbed l-attenzjoni ikun hemm il-ġurnalisti a quddiem il-pulizija a ħa
# dia_task_pics02_13f_10m_spk_1_31	142.4	158.18	u t-tielet waħda ovvjament l-istampa qed tiġri għal xi maratona han dan-numru fuq fuq tix-il-ġerżi tagħha u l-teasheirt bomda qiegħda fiha ambjent e fil-beltani ui jidlu s-siġġar wara
# dia_task_pics02_13f_10m_spk_1_33	161.42	186.8	qegħdin jiġru fl-istess ħin mhix isase just joging eħe m' jidhix li xi ġirja imma insomm għanda l-wann fuq il-in-numru li wieħed tnejn zero jiġifieri i eqq a meta tmur tagħmel joging waħdek m' għandek bżonn in-numru aj min jiġifieri inmmaġinali xi tellieqa forsi ħqed jgħixu en t' hawn
# dia_task_pics02_13f_10m_spk_1_35	189.16	191.2	um għaddejja bret ma' imgħaġġel u
# dia_task_pics02_13f_10m_spk_1_37	193.64	215.38	x'tip ta' ħajja timmaġina li jgħixu n-nies f'dawn l-istampi dana għandu xi xogħol hekkħa neħduh bħal elisejjer għax-xogħol li jrid ikun dejjem pulit e bis-sut u hekk mhux għandhom xi drescod fieri tal-uffiċċju biex mhux jaqbad u jilbes l-affarijiet li jrid u jmexxi
# dia_task_pics02_13f_10m_spk_1_39	216.64	226.34	jew forsi xi lecċurere tal-universàta u jista' jkun ukoll donnhum ma do insomma ma nistgħux ngħidu hekk hux żgħir ħafna jew kbir ħa ħa
# dia_task_pics02_13f_10m_spk_1_41	227.48	233.68	e l-oħrajn qegħdin għaddejjin ma ma tantx huwa żmien sabiħ
# dia_task_pics02_13f_10m_spk_1_43	234.92	252.84	imma serjenarze ija imma xorta gall-ambjent ta' fejn qegħdin mhuwiex daqshekk żgur e pjaċevoli tara dawk is-suldati libsinekk istampa tal-ordarna irlandi ma nafx ma nistax nqlaq għas-s ilt-kliem hemmhekk u l-oħra bħa speċi
# dia_task_pics02_13f_10m_spk_1_45	254.78	262.02	dejjem għed themmiq t' ammira għal xi għax għandha asperazzjoni li forsi xi darba tkun tirbaħ
# dia_task_pics02_13f_10m_spk_1_47	263.28	264.94	'il xi tellieqa jew hekk
# dia_task_pics02_14f_03m.tsv
# {'Spk 1 Machine', 'Spk 2 Machine'}
# dia_task_pics02_14f_03m_spk_0_0	0.0	3.82	eħe hekk qekk jidher atal-mod kif inhuma libsin u
# dia_task_pics02_14f_03m_spk_0_3	5.06	8.58	iżli maltirmakontevittant eħe hekk hu e l-ewwel mistoqsija
# dia_task_pics02_14f_03m_spk_0_5	10.0	15.02	eħe x'tista' tkun ir-raġuni ngħid le dawn in-nies qed jiġru
# dia_task_pics02_14f_03m_spk_0_7	16.72	20.18	u elwieħed for si ed-tard tax-xogħol ilfinzjaw pintament kien daqsxejn terd eħe ħe ħejjaq jew hekk jien għalija fhemm uwa kif inhu meħut ir-ritratt u hekk
# dia_task_pics02_14f_03m_spk_0_9	21.98	32.84	pjuttost qisu xi fotoshut ta' xi xi moda xi ħwejjeġ xi
# dia_task_pics02_14f_03m_spk_0_11	34.2	38.52	x' jidher wisq pulit dar-raġel
# dia_task_pics02_14f_03m_spk_0_13	39.7	41.02	u anka il-il-l-is-fl-isfond dawm affarijiet qishom
# dia_task_pics02_14f_03m_spk_0_15	42.36	46.52	sbieħ e ppjanati żjuru om taż-lis-sbuħija tal-libsa l-ilia eħe eżatt eżatt eħaisu l-ġirja tiegħu hija waħda mhux eħe minn xtart qiu x'jiġri juw u x' qed imma e rridu naħseb nassumu li qed jiġri hux hekk
# dia_task_pics02_14f_03m_spk_0_17	48.0	62.26	eħenn pulit ħafna l-ġlekk tiegħu jidher e
# dia_task_pics02_14f_03m_spk_0_19	66.62	70.4	li s-swieħ kemxa flus ħu
# dia_task_pics02_14f_03m_spk_0_21	72.02	73.72	roboimselli biss il-veri iiva
# dia_task_pics02_14f_03m_spk_0_23	76.26	77.94	ma lafx t-tini stampa ħakien a
# dia_task_pics02_14f_03m_spk_0_25	80.2	82.7	melax taħseb jidhir li hemm isu xi protesta naħseb għaddejja ixhemm dak ħum i-pulizija kollha jew ħuħm inqata' xi aċċident biex għamd dak tak kullu ħeħe ghux hekk xi rewwiex tiegħu hekk qishom
# dia_task_pics02_14f_03m_spk_0_27	84.36	95.04	eħe u u allura qisu ġiegħlek taħseb huli
# dia_task_pics02_14f_03m_spk_0_29	96.36	99.24	li dawn in-nies qed jitilqu minn djarhom naħseb fis-sens imma l-bandal-aħra ma tantx għandhom bagaljibrihom ħuu assu mela għax jekk ixtri bugelli ta' xi vjolin jew xi instrument ma nafx x' għandha f' idha eeħ eħ hemm
# dia_task_pics02_14f_03m_spk_0_31	101.48	114.64	ma nafx jista tieħu l-impressjoni li allavolja hemm din il-protesta euro ista aħna għandna ħajjitna u rridu nkomplu għaddejjin bl-affarijit iet ħemmna ppjanant qqisu se jirxi ma nafx forsi t-tifel sejħer xi lezzjonijiet tal-vjolin jew xi ħaġa hekk ma nafx joqgħod vjolin imma il
# dia_task_pics02_14f_03m_spk_0_33	116.2	131.78	jew trumnweftaħ el basktijiet huma f' żgħar biex tiże eħe tajjeb u ta' għamla partikolari wkoll fis-sens
# dia_task_pics02_14f_03m_spk_0_35	133.8	140.94	eħe ma nafx eżatt
# dia_task_pics02_14f_03m_spk_0_37	142.16	143.14	u għalkemm abjad u iswed il-ir-ritratt
# dia_task_pics02_14f_03m_spk_0_39	144.54	147.48	għandi f'moħħi li huwa pjuttost modern al- ħe anka l-mod ta' speċjalment tax-xalla u l-iskofja eħe eħ lis-eħ l-iskufja tat-tifel qis għandha x gaż-żet eħa ħ
# dia_task_pics02_14f_03m_spk_0_41	149.02	160.6	għandha xi ditta il-qd forsi qegħdin naraw wisq fil-tagħna imma ħeġa q iġġiegħelna naħseb li hija huwa ritratt modern però forsi moħħnax għara din i u tax tsmi l-ħwerra pereżempju anki jiena kif għed tgħidx intiflif il-xi nojs 'il-bustijiet u hekk għed tommmhux dassebkanti kif qed tgħid inti ħum naħseb
# dia_task_pics02_14f_03m_spk_0_43	162.1	181.44	ħuħġbied forsi illi kien hemm manafx reċentement jegħek fil-irlanda ta' fuqu u ħeħe ma nafx fin-nit forsi eħe jista' juau anki l-lell miegħu il-tal-tal-pulizija
# dia_task_pics02_14f_03m_spk_0_45	183.42	195.32	eħ hemm min nifhem qed
# dia_task_pics02_14f_03m_spk_0_47	196.64	197.64	jekk qed jiġru i xi ħaġa qegħdin jiskartaw xi forma ta' problem problemi hemm
# dia_task_pics02_14f_03m_spk_0_49	199.72	205.22	imbagħad imbagħad hemm l-aħħar stampa u t-tielet stampa
# dia_task_pics02_14f_03m_spk_0_51	211.02	213.22	t-tielet stampa naħseb hija aktar ċara iktar ċara mill-oħra għalija
# dia_task_pics02_14f_03m_spk_0_53	215.86	220.36	eħeħe mhix qiegħda taħrab minn xi ħaġa żgur
# dia_task_pics02_14f_03m_spk_0_55	222.36	225.34	għidtkommila naħseb għax priż hi wara eżatt eżatt ki hemm raġuni għax xiex qid ħum
# dia_task_pics02_14f_03m_spk_0_57	227.6	231.9	naħseb xi maratona wkoll għax għandha n-numru mid-daw li jiddendlu mal-flokkijiet jew jitwaħlu eħ aħseb xi tip ta' maratona jien ħaħseb
# dia_task_pics02_14f_03m_spk_0_59	233.9	243.02	mhux hawn malak
# dia_task_pics02_14f_03m_spk_0_61	244.7	245.24	idejjem mhux qsiġar għal malta
# dia_task_pics02_14f_03m_spk_0_63	247.0	248.14	e eħ
# dia_task_pics02_14f_03m_spk_0_65	250.0	250.82	għid emm hemm mistoqsija oħra x'tip ta' ħajja timmaġina li jgħixu n-nies fl-istampi
# dia_task_pics02_14f_03m_spk_0_67	253.9	259.06	ma qisna iżnabdie għadniehom u ke fis-sens seħ aħ
# dia_task_pics02_14f_03m_spk_0_69	260.36	264.02	eħa ma nafx nkomplux ngħidu iktar fu fuq dil-għaġa jew fuq
# dia_task_pics02_14f_03m_spk_1_0	0.0	3.82	dat-tliet istampiet naħseb qed jiġru kollha skopijiet differenti
# dia_task_pics02_14f_03m_spk_1_3	5.06	8.58	eħe hekk qekk jidher atal-mod kif inhuma libsin u
# dia_task_pics02_14f_03m_spk_1_5	10.0	15.02	iżli maltirmakontevittant eħe hekk hu e l-ewwel mistoqsija
# dia_task_pics02_14f_03m_spk_1_7	16.72	20.18	eħe x'tista' tkun ir-raġuni ngħid le dawn in-nies qed jiġru
# ...
# mono_recipe_22f_spk_0_6	63.68	64.38	lanqas nista' ngħidilha għaġir għax tkun naqra twaħħal fil-fatt aħjar tuża ftit kon flawer tagħmilhom qishom boċċi boċċi fuq karta jiena nħobb nuża l-baking paper ħalli ma jeħlux u lewża sħiħa fin-nofs tħallihom joqogħdu ftit dik qisha nofs siegħa
# mono_recipe_22f_spk_0_8	66.38	84.56	forn jekk ikun diġà msaħħan tant aħjar
# mono_recipe_22f_spk_0_10	85.86	87.96	fi żmien għoxrin minuta jkunu lesti u mbagħad tgħidli x'inti
# mono_retell_vid01_02f.tsv
# set()
# mono_retell_vid02_06f.tsv
# set()
# mono_retell_vid02_06m.tsv
# set()
# mono_retell_vid02_10m.tsv
# set()
# mono_retell_vid02_11f.tsv
# set()
# mono_retell_vid02_12f.tsv
# set()
# mono_retell_vid02_13f.tsv
# set()
# mono_retell_vid02_14f.tsv
# set()
# mono_retell_vid02_17f.tsv
# set()
# mono_retell_vid02_21f.tsv
# {'Machine'}
# mono_retell_vid02_21f_spk_0_2	1.28	4.94	e li kien xtaq qisu jipprova jibni d-dar tiegħu u kellu mappa żgħira tliet affarijiet kollox bhiex joħloq id-dar tiegħu imma
# mono_retell_vid02_21f_spk_0_4	6.12	13.46	kif beda joħloq id-dar bdew deħlin in-nies oħrajn fuqu hemm annimali oħra li kienu joqogħdu wkull taħt l-art hemm u juruh id-djar tagħhom u e
# mono_retell_vid02_21f_spk_0_6	15.28	25.28	kull e
# mono_retell_vid02_21f_spk_0_10	28.76	39.04	tliet em kdar mimlija u attrezzata qiża bil-kċina u kemm minn hekk kellu spaw minn kollox kien hemm hemm
# mono_retell_vid02_21f_spk_0_12	41.24	49.74	u xin beda jara
# mono_retell_vid02_21f_spk_0_14	50.82	51.48	hemm dawn tagħha hu beda jdur u jfittex emm fejn jista' anka jibni tiegħu baqa' niżel 'l isfel iktar ma jinżel isfel ektor sip-djar differenti ta' nies differenti ta' nimal differenti hem u jidħol ġo liberrija daqshiex ibqa' nieżel jibqa' spiċċa banju ta' xwieħed i mbagħad jerġibh għaddej jibqa jħaffer hemm
# mono_retell_vid02_21f_spk_0_16	53.1	71.54	sab restor għand ukoll ta' xi nemel hemm u jibqa' nieżel u jħaffers biex jipprova sib post fejn joqgħod hemm u jkun jista' jibni d-dar tiegħu hemm għand ma setax isib post minħabba dawn l-annimali kollha u der kbar li kelbru-li kebruuma
# mono_retell_vid02_21f_spk_0_18	73.06	89.1	e spiċċa niżel s' isfel nett fej imbagħad
# mono_retell_vid02_21f_spk_0_20	90.32	93.04	taħt nett tal-art sa fejn kien wasal hemm kien hemm l-ilma hemm u xquq li bda telaq in ġor ħamrija e
# mono_retell_vid02_21f_spk_0_22	94.64	103.92	u kif beda e
# mono_retell_vid02_21f_spk_0_24	105.14	105.9	u minħabba f' hekk x jin beda kien ħa jibda jbni d-dar tiegħu hemmhekk daħlu beda dieħel l-ilma bil-mod il-mod u
# mono_retell_vid02_21f_spk_0_26	107.0	113.62	ovvjament minħabba t-toqba li bda ħalu qu minn fuq nett e u nifed fid-dja tal-oħrajn faċilment dal-ilma seta' jibqa' tiela' u jidħol jinfed fid-djar l-oħra tan-tal-annimali l-oħra hemm
# mono_retell_vid02_21f_spk_0_28	115.2	126.48	u ħaf hekk u beda tiela' u tiela' biex ipprova jarassaha minħabba l-ilma biex ma laħaqx e
# mono_retell_vid02_21f_spk_0_30	127.78	132.08	hemm djar l-oħrajn u
# mono_retell_vid02_21f_spk_0_32	134.34	135.96	ħabbat bieb meta ltaqa' ma' dar u ħareġ
# mono_retell_vid02_21f_spk_0_34	137.58	140.68	annimal minnhom għemli għajjat hemm uriħ riħ ta spjegalu bil-mossi x' kien qed jagħmel dan il-fenek hemm u x' ħinqallu hemm da l-annimal
# mono_retell_vid02_21f_spk_0_36	142.56	154.26	għajjat waħda biex jabża' lill-oħrajn lel kien jgħixef id-djar li kien hemm l-oħra taħt l-art u dawn ġew kollha jiġru hemm fehmuh ġew kollha u bdew jgħinu hemm
# mono_retell_vid02_21f_spk_0_38	155.68	168.02	jgħinu 'l xulxin biex jeqhem jagħlqu t-toqba li kien ħoloq u jgħaddu l-ilma impost differenti biex ma jaldin l-ilma jibqax tiela' sad-djar hemm u mbagħa fl-aħħar iddeċidew dawn l-oħrajn l-annimali biex ikom-jgħin komplijejnuh u għenuh jibni ukoll dar aħjar għalih hemm dan il-fenek sa fl-aħħar imbagħad kellu dar b fuq bi anki b' tal-posta fejn jirċivielha ittri hemm
# mono_retell_vid02_21f_spk_0_41	176.89876284023677	192.18	il-messaġġ li rajt qisu fih
# mono_retell_vid02_21f_spk_0_43	193.8	195.3	hemm l-ewwel li rajt kien u naħseb żewġ messaġġi l-ewwel messaġġ kien
# mono_retell_vid02_21f_spk_0_45	196.94	202.22	emm dan il-fenek meta l-ewwel ħaġa li kien ħa janki ħa jibni d-dar tiegħu u kellu l-pjan żgħir sempliċi ħafna kien donnu kuntent ħafna b' dak il-pjan semxilli kellu tad-dar kien kuntent b' dik id-dar żgħira li kien ħa joħloq imma mbagħad meta beda jara il-l-annimali l-oħra u d-djar li bnew huma bdela jara ax-hemm qisu tiegħu kienet sempliċi ż żżejjed ħdejtel l-oħrajn u ma kienx qisu kuntent b' dik is-sempliċità hemm
# mono_retell_vid02_21f_spk_0_47	203.52	227.56	naħseb tirrifletti wkoll e l-ħajja tagħna jiġifieri meta taraw xi ħaġa ta tala tkun sabiħa komla sempliċi mbagħad tiġi influwenzat minn ħaddieħor u ma tkunx kuntent dak li għandek e it-tieni messaġġ li rajt fih kien imbagħad lejn l-aħħar meta il-bqija tal-innimali ddeċidew li jgħinuh kollha ħadmu flimkien hemm ħadd ma gergirlu għax inti inhemm
# mono_retell_vid02_21f_spk_0_49	228.8	249.86	intfittilna hemm
# mono_retell_vid02_21f_spk_0_53	254.24	255.92	kant sa daħlu fid-djar tagħna minflok għenuh qabdu imxew ħadmu flimkien u bnuh u anka mbagħad biex jibni d-dar tiegħu u jagħmluh kemm jista' jkun komdu u laqgħuh ukoll fin-naħa tagħhom
# mono_retell_vid03_01f.tsv
# set()
# mono_retell_vid03_02f.tsv
# {'Machine'}
# mono_retell_vid03_02f_spk_0_0	0.0	3.62	żewġt irġiel
# mono_retell_vid03_02f_spk_0_3	5.08	5.68	u tifel żgħir telgħu fuq d-dgħajsa żgħira
# mono_retell_vid03_02f_spk_0_5	6.86	10.66	f'nofs il-baħar u qatfu 'l barra
# mono_retell_vid03_02f_spk_0_7	12.48	14.68	kellhom ill-anterna mixgħula fuq id-dgħajsa
# mono_retell_vid03_02f_spk_0_10	18.08	20.14	meta tela' l-qamar il-qamar kwinta
# mono_retell_vid03_02f_spk_0_12	21.52	24.16	iddeċidew illi issa l-mument illi jitfgħu l-anterna
# mono_retell_vid03_02f_spk_0_14	26.04	30.5	u jibdew ix-xogħol li għalih kienu ħarġu fuq il-baħar
# mono_retell_vid03_02f_spk_0_16	31.74	35.3	x' għamlu
# mono_retell_vid03_02f_spk_0_20	40.64	42.82	u mbagħad poġġew sellum
# mono_retell_vid03_02f_spk_0_22	44.22	46.8	fi fil-pruwa tad-dgħajsa sellum tiela fil-għoli
# mono_retell_vid03_02f_spk_0_24	48.18	52.02	u t-tifel tela' bl-ankra f' idu mas-sellum sakemm laħaq il-qamar kwinta
# mono_retell_vid03_02f_spk_0_26	53.16	61.36	it-tivel niżel fuq il-qamar
# mono_retell_vid03_02f_spk_0_28	63.74	65.0	ra lli l-ankra qiegħda soda
# mono_retell_vid03_02f_spk_0_30	67.18	69.7	mal-art tal-qamar
# mono_retell_vid03_02f_spk_0_33	72.58	74.5	it-tlett irġiel imbagħad setgħu jitilgħu huma wkoll
# mono_retell_vid03_02f_spk_0_35	76.68	79.16	meta telgħu hemm niżlet shueting star kbira
# mono_retell_vid03_02f_spk_0_37	81.28	84.96	sabiħa deh bija
# mono_retell_vid03_02f_spk_0_39	86.68	87.42	u din is-shuting star it-tifel
# mono_retell_vid03_02f_spk_0_41	89.28	91.14	ta' daqqa ta'
# mono_retell_vid03_02f_spk_0_43	92.28	92.92	mazza li kellu f'idu
# mono_retell_vid03_02f_spk_0_45	94.36	95.3	u din ix-shueting starr kbira saret elf stilla de bija sabiħa
# mono_retell_vid03_02f_spk_0_47	97.54	103.24	li xterdet mal-qamar kollu
# mono_retell_vid03_02f_spk_0_49	104.48	106.3	imbagħad qabdu
# mono_retell_vid03_02f_spk_0_51	109.7	110.28	żewġt irġiel u t-tifel qabdu
# mono_retell_vid03_02f_spk_0_53	111.72	112.9	l-apparat li kellhom xi xkupa u affarijiet oħra u pala u bdew iressqu jressqu jressqu daid-deheb stillel tad-deheb li kien hemm fuq il-qamar resquhom naħa waħda tal-qamar b'tali mod
# mono_retell_vid03_02f_spk_0_55	114.54	129.6	illi meta niżlu lura
# mono_retell_vid03_02f_spk_0_57	130.98	132.72	fuq id-dgħajsa bis-sellum u ħarsu 'l fuq
# mono_retell_vid03_02f_spk_0_60	136.9	138.28	flok qamar kwinta
# mono_retell_vid03_02f_spk_0_63	141.36	144.34	nofs qamar jew felli ta' qamar għax fil-fatt meta resqu dawk l-istilel debin kienu qegħdin ineħħu
# mono_retell_vid03_02f_spk_0_66	149.74224969282295	166.76	mela darba f'nofs ta' lejl
# mono_retell_vid03_02f_spk_0_67	154.7	156.06	dik il-il-l-qdija minn fuq wiċċ il-qamar u resquha lejn ġenb u allura jekk ġie f' qamar felljow jew n
# mono_retell_vid03_11f.tsv
# set()
# mono_spont00_06f.tsv
# set()
# mono_spont00_09m.tsv
# set()
# mono_spont00_11f.tsv
# set()
# mono_spont00_22f.tsv
# {'Machine'}
# mono_spont00_22f_spk_0_2	1.7	30.24	emm jiena ninnutaha li anke r-rispett
# mono_spont00_22f_spk_0_4	31.7	34.58	bejn bniet u subien ikun aħjar milli bniet biss jew subien subien biss sallimt u bniet tbiss għallimt ukoll imħallten aħjar jien sibt aħjar però bħala komunikazzjoni lelel now problem
# mono_spont00_22f_spk_0_6	36.24	49.28	m' hemm problema ass
# mono_spont01_21f.tsv
# {'Machine'}
# mono_spont01_21f_spk_0_0	0.0	16.38	mor id-dar naqra xi ftit mill-ktieb li nkun qed naqra dak il-ħin
# mono_spont01_21f_spk_0_3	18.52	21.28	hemm ja xi ħaġa b' mod nirrilassa wkoll il-qari
# mono_spont01_21f_spk_0_6	26.48	27.6	forsi nsajru xi ħaġa għara nofsinhar mal-familja
# mono_spont01_21f_spk_0_8	29.28	31.62	nieklu u mbagħad waranofsinhar hekk speċjalment nhar ta' ħadd inħobb immur noħroġ xi dawra ma' jomju fil-kampanja il-baħar skont it-temp u skont l-istaġun hemm
# mono_spont01_21f_spk_0_10	33.84	44.0	forsi ma' xi ħbieb hemm niltaqgħu flimkien hemm jaf inġibu xi ħaġa x' nieklu wkoll filgħaxija k nqattgħu naqra nofstanhar flimkien hemm ni-hemm jew xi logħob iġibiex logħob magħna nidtqu ċaċraw insomma tkellmu flimkien hemm xi mkien hekk però fin-natura fejn irrilassa hemm
# mono_spont01_21f_spk_0_12	45.54	64.8	u nqatta' ftit man-nies l-aktar li nħobb -iktar għill-viċin tiegħi mat filgħaxija is-soltu nsomma adoxxa u tlesti għas-sodda
# mono_spont01_21f_spk_0_13	66.39113856956656	75.02	emm naħseb il-ġurnata addejali tiegħi jew xi ħaġa hekk sabiħa kif inqatta' nħobb inqatta' xi ġurnata hekk kalma kimm jista' jkun allura e forsi filgħodu noħroġ mixja bil-kelb nogħmo f' nofs siegħa miexi hekk jieħu gost ixammem naqra dak u jmur naqra dawra imbagħad hemm
# mono_spont02_22f.tsv
# {'Machine'}
# mono_spont02_22f_spk_0_4	51.84	59.62	għandna ħafna barranin fl-iskola fejn qiegħda jien is-sena l-oħra kien kellna sixty one peircent and ye woned bil-liv id minn fejn jiġu u mbagħad hekk niġi konxja ngħid mela s-sinjal li malta għandna xi ħab la kuntenti huma la kuntenti hawnhekk ġieli jiġifieri kelli klassijiet klassi sħiħa barranin biss
# mono_spont02_22f_spk_0_6	61.64	84.12	taljani l-iżjed taljani u sqallin il-biċċa l-kbira imma l-bqija misserbja mill-lukrejina anke minn pajjiżi sawt inkredibbli
# mono_spont02_22f_spk_0_8	86.56	96.86	inkredibbli kemm jiġu minn pajjiżi u kultant issib anke ingliżi tgħid possibbli mill-ingilterra xi meta ġieli mort l-ingilterra ngħid aħħ hawn sew kieku ngħixhaw kieku ngħixha imma mbagħad tiġi pajjiżek u tispiċċa tgħallimhom tgħid imma daw għall-ewwel tgħid x'raw
# mono_spont02_22f_spk_0_10	98.4	115.9	imbagħad tgħid eħe dawn is-seti li jagħti tajjeb hawn u mbagħad issib studenti oħra li imsieken jiġu
# mono_spont02_22f_spk_0_12	117.96	123.14	għax imkaxkrin għax imġagħlin mill-ġenituri għax isibu xogħol hawn allura għiduna raktar ma jissetiljaw jew inkunu dawk jew inkella jkunu dawk li ngħidulhom studenti li iktar li joħolqulek trabil għax ikunu mġiegħlin fl-istess inli nqas ittihom tort fl-istes ima tagħti x' tort lilna għaliex
# mono_spont02_22f_spk_0_14	124.34	141.32	ħeqq il-bhevjer ħeqq ħana nkunu rridu bhevier kemm jista' jkun perfett mal-perfett ma tantx għadu je
# mono_task_mmap03_02f.tsv
# set()
# mono_task_pics01_02f.tsv
# set()
# mono_task_pics01_07m.tsv
# set()
# mono_task_pics01_11f.tsv
# {'Machine'}
# mono_task_pics01_11f_spk_0_0	0.0	4.32	tliet stampi differenti hemm u għandek żewġ mistoqsijiet ħdejn dawn l-istampi għaliex taħseb li dawn in-nies fl-istampiqed għaliex taħseb li dawn in-nies fl-istampi qed jagħmlu dawn l-attivitajiet fi grupp x' taħseb li qegħdin iħossu waqt li qed jagħmlu dawn l-attivitajiet mela
# mono_task_pics01_11f_spk_0_3	5.86	21.22	orrajt mela fl-ewwel ritratt qed nara hemm
# mono_task_pics01_11f_spk_0_5	24.6	28.94	qed nara żewġ fajliet
# mono_task_pics01_11f_spk_0_7	30.38	32.06	ħerġin minn ġo ħanut tal-ħwejjeġ
# mono_task_pics01_11f_spk_0_9	33.68	35.68	għandhom ħafna pastijiet f' idejhom jiġifieri nimmaġina li ħadu gost għaliex
# mono_task_pics01_11f_spk_0_11	37.34	41.78	e mhux għax nefquhom għax xtraw għax xtraw il-ħwejjeġ naħseb għa xtraw il-ħwejjeġ ħwejjeġ li jogħġbuhom hemm lanqas hekk n emel-me meta nara din l-istampa niftakar hemm e
# mono_task_pics01_11f_spk_0_13	42.86	56.12	fiha f' oħti fmill darba mmorru li qidu ngħidu ħa immurr u nixtru naqra u naqra ħwejjeġ flimkien u e isservi wkoll bħala bħala bonding time ukoll
# mono_task_pics01_11f_spk_0_17	69.68	70.88	u naħseb ukoll li jista' jkun l'l dawn id fal dan dawn dawn żewġ fajliet jista' jkun e
# mono_task_pics01_11f_spk_0_19	72.9	78.42	apparti li servihom bħala ħarġa wara ħarġa biex imorru jixtru u jixtru l-ħwejjeġ għax għandhom bżonnhom jista' isa-sservihom ukoll bħala
# mono_task_pics01_11f_spk_0_21	79.96	87.44	hemm ħin li jistgħu kif għidtlek kif kif għidt bonding time jiġifieri qed qed e jitkellmu fuq affarijiet li normalment inħabba l-ħajja maġa ma jkollhomx ċans jitkellmu e mill-ħajja li il miq mil minn ma mx għaddew pereżempju fdik il-ġimgħa hemm x x-xa x' għandhom ppjanat għal għal għall ġejjieni għal
# mono_task_pics01_11f_spk_0_23	90.4	111.64	għall-ġimgħa ta' ta' wara pereżempju
# mono_task_pics01_11f_spk_0_26	115.96	117.64	hekk naħseb
# mono_task_pics01_11f_spk_0_30	121.36	124.12	għandek qed nara
# mono_task_pics01_11f_spk_0_32	127.32	128.06	gruppi ta' persuni
# mono_task_pics01_11f_spk_0_34	130.0	131.2	li qegħdin jitilgħu qisu mond-mhux qisu qed jitilgħu qisu montanja
# mono_task_pics01_11f_spk_0_36	133.08	138.36	e gruppi żgħar ta' tlieta ħames persuni hemm
# mono_task_pics01_11f_spk_0_38	140.46	145.92	jista' jkunu ħbiebi jista' jkunu familja imma egen nerġa' ngħid li
# mono_task_pics01_11f_spk_0_40	148.72	154.0	esperjenza hekk għalkemm hija
# mono_task_pics01_11f_spk_0_42	156.06	157.66	hija tqila titla' mundanjah ħangħiduha kif inhi hemm
# mono_task_pics01_11f_spk_0_44	158.98	162.62	meta tkun fi grupp
# mono_task_pics01_11f_spk_0_46	164.0	165.04	ħafna aħjar milli tkun waħdek għax ittiħtat il-kuraġġ ta' tagħti kuraġġ lil tah ta' miegħek
# mono_task_pics01_11f_spk_0_48	166.8	171.52	ek tkun waħdek konki tista tgħid hija ejja hija baqnaqbaq naħ ħarbaq naħar oħra ejja nista' nagħmilha nista' nagħmilha immeta jkun hemm xi ħadd ekk ċwily għine jgħidlek dawn l-affarijiet xaħaqq naħseb
# mono_task_pics01_11f_spk_0_50	172.94	183.24	għal sfida bħal din li titla' mmuntanja naħseb li eħe għalhekk qegħdin fi gruppi biex jgħinu lil xulxin biex jagħmlu kuraġġ 'il xulxin
# mono_task_pics01_11f_spk_0_53	192.46	194.94	qed nara t-tielet stampa li t-tliet stampa e għandek omm jew carer emm
# mono_task_pics01_11f_spk_0_55	196.56	205.2	tista' tkun ukoll ta' hemm ticher ma ħsibx imma naħseb l-iktar omm omm u
# mono_task_pics01_11f_spk_0_57	206.66	212.68	u todler letteralment to dler qed tgħin e qed qed qed qed isajru flimkien qed jagħmlu xi tip ta' jew xi kejk xi ħaġa xi ħaġa hekk xi tip xa' xi kejk jew xi pasti hemm u qed qed qed jitbissmu f' lu qed jitbissmu t-tejn li huma u donnha qet tnejn qed jieħdu gost it-tnejn qet li qed qed qed e qed jieħdu gost speċjalment dit-tifel qed qed qed jieħu gost isajjar u naf li qed jieħu gost isajjar għaliex jien għandi todler u għandi għandi bejbi ta' sentejn u letteralment togħxot aqta u għaxart eu stajjar miegħi
# mono_task_pics01_11f_spk_0_61	253.76	254.98	naħseb li attività hekk tgħn ħafna gen bil-bil-bonding bejn l-omm bejn il-carer u i il-it-tifel jew it-tifla tagħha għaliex
# mono_task_pics01_11f_spk_0_64	268.16	270.3	affari i t tnissik mill-ħajja maxxa ta' kuljum u tkun tista' tiffoka fuq ħaġa waħda tiffoka fuq dik l-attività ma' mat-tifel u t-tifel tiegħek jew t-tifel it-tifel jew it-tifel tagħha
# mono_task_pics01_11f_spk_0_66	285.746477832213	287.04	issa qed nara tliet tliet stampi oħra hemm
# mono_task_pics01_11m.tsv
# set()
# mono_task_pics02_07m.tsv
# set()
# mono_task_pics02_11f.tsv
# set()
# mono_task_pics03_02f.tsv
# set()
# mono_task_pics03_07m.tsv
# set()
# mono_task_pics03_11m.tsv
# set()

# %%
# torchaudio.save('mt_en/dia_spont01_13m_14m_spk_0.wav', resampled_wav, 16000)
# torchaudio.save('mt_en/dia_spont01_13m_14m_spk_1.wav', resampled_wav[1:], 16000)

# %%
all_df['n_frames'].sum() / 16000 / 3600
# Out:
# 0.8228403472222222

# %%
asr_iwslt_df = all_df.copy()

# %%
split_ratio = [0.9, 0.1]
n_sample = len(asr_iwslt_df)
indices = list(range(n_sample))
random.shuffle(indices)
asr_iwslt_train_df = asr_iwslt_df.iloc[indices[:int(n_sample * split_ratio[0])]].sort_index().copy()
asr_iwslt_dev_df = asr_iwslt_df.iloc[indices[int(n_sample * split_ratio[0]):]].sort_index().copy()

# %%
save_df_to_tsv(asr_iwslt_train_df, os.path.join(mustc_root, 'train_asr_mt_iwslt.tsv'))
save_df_to_tsv(asr_iwslt_dev_df, os.path.join(mustc_root, 'dev_asr_mt_iwslt.tsv'))

# %% [markdown]
# # ASR from CommonVoice

# %%
root = '{}/mt'.format(path_to_commonvoice)
asr_audio_root = os.path.join(root, 'clips')
new_wav_root = '{}/mt-en/data/asr/wav'.format(path_to_mustc)
mustc_root = path_to_mustc

# %%
ori_df = load_df_from_tsv(os.path.join(root, 'validated.tsv'))

# %%
ori_df
# Out:
#                                               client_id  \
# 0     119ecbc0c91da642d62bcc7b87db0e6bc4c104715290ca...
# 1     2812a0daa8849062529bbe704f20be91c8667a03445da9...
# 2     4328dce099b8584ea25b687213a72ea7d7666c88f09ab3...
# 3     4e65a29d25e88c47b77cda815a5f1ec02097c8b4102a66...
# 4     5136da6537f4a0d4acf487b0f8e9d6546405f0ee393d1d...
# ...                                                 ...
# 6378  013358357c251280edcdc585291df70be4d52c209c3d39...
# 6379  013358357c251280edcdc585291df70be4d52c209c3d39...
# 6380  013358357c251280edcdc585291df70be4d52c209c3d39...
# 6381  013358357c251280edcdc585291df70be4d52c209c3d39...
# 6382  013358357c251280edcdc585291df70be4d52c209c3d39...
#
#                               path  \
# 0     common_voice_mt_22259676.mp3
# 1     common_voice_mt_22463716.mp3
# 2     common_voice_mt_22196702.mp3
# 3     common_voice_mt_23742149.mp3
# 4     common_voice_mt_21921959.mp3
# ...                            ...
# 6378  common_voice_mt_21991213.mp3
# 6379  common_voice_mt_22176840.mp3
# 6380  common_voice_mt_22177053.mp3
# 6381  common_voice_mt_22205002.mp3
# 6382  common_voice_mt_22205324.mp3
#
#                                                sentence  up_votes  down_votes  \
# 0     Ix-xogħol mistenni jibda dan ix-xahar stess u ...         2           0
# 1     It-tifla rringrazzjatha ta' dak kollu li għaml...         2           0
# 2     Bl-ikbar responsabbilta' nerġa' ntenni li jien...         2           0
# 3     Jiena nsib ruħi idjota niddiskuti affarijiet l...         2           0
# 4     Jekk hemm problema hemm problema u wieħed irid...         2           0
# ...                                                 ...       ...         ...
# 6378  Issa ħalli nispjega xi ħaġa għax hija importanti.         2           0
# 6379     Jekk nara dan it-taħżiż hawn, nista' nkun naf?         2           0
# 6380  Ovvjament hemmhekk imbagħad inqabad, intbagħat...         2           0
# 6381  Kienu jgħidu: Aħna niddeċiedu mbagħad niġu qud...         2           0
# 6382  Imma jekk ikun hemm firma ta' żewġ uffiċjali h...         2           0
#
#           age  gender accents variant locale segment
# 0                                         mt
# 1                                         mt
# 2     fifties    male                     mt
# 3                                         mt
# 4                                         mt
# ...       ...     ...     ...     ...    ...     ...
# 6378  fifties  female                     mt
# 6379  fifties  female                     mt
# 6380  fifties  female                     mt
# 6381  fifties  female                     mt
# 6382  fifties  female                     mt
#
# [6383 rows x 11 columns]

# %%
new_df = pd.DataFrame(columns=['id', 'audio', 'n_frames', 'src_text', 'speaker', 'src_lang'])

id = []
audio = []
n_frames = []
src_text = []
speaker = []
src_lang = []

for row in tqdm(ori_df.iterrows(), total=len(ori_df)):
    idx, row = row
    
    ind = row['path'][:-4]

    wav, rate = torchaudio.load(os.path.join(asr_audio_root, ind + '.mp3'))
    resampled_wav = torchaudio.functional.resample(wav, orig_freq=rate, new_freq=16000)
    torchaudio.save(os.path.join(new_wav_root, ind + '.wav'), resampled_wav, 16000)
    # os.makedirs('/mnt/data/siqiouyang/datasets/must-c-v1.0/mt-en/data/asr/align_mfat/' + row['client_id'][-10:], exist_ok=True)
    # torchaudio.save(os.path.join('/mnt/data/siqiouyang/datasets/must-c-v1.0/mt-en/data/asr/align_mfat/', row['client_id'][-10:], ind + '.wav'), resampled_wav, 16000)

    id.append(ind)
    audio.append('mt-en/data/asr/wav/{}.wav'.format(ind))
    n_frames.append(int(resampled_wav.size(1)))
    src_text.append(row['sentence'])
    speaker.append(row['client_id'][-10:])
    src_lang.append('mt')

new_df['id'] = id
new_df['audio'] = audio
new_df['n_frames'] = n_frames
new_df['src_text'] = src_text
new_df['speaker'] = speaker
new_df['src_lang'] = src_lang
# Out:
# 100%|██████████| 6383/6383 [00:59<00:00, 107.44it/s]

# %%
new_df['n_frames'].sum() / 16000 / 3600
# Out:
# 8.276866666666667

# %%
asr_cv_df = new_df.copy()

# %%
split_ratio = [0.9, 0.1]
n_sample = len(asr_cv_df)
indices = list(range(n_sample))
random.shuffle(indices)
asr_cv_train_df = asr_cv_df.iloc[indices[:int(n_sample * split_ratio[0])]].sort_index().copy()
asr_cv_dev_df = asr_cv_df.iloc[indices[int(n_sample * split_ratio[0]):]].sort_index().copy()

# %%
save_df_to_tsv(asr_cv_train_df, os.path.join(mustc_root, 'train_asr_mt_cv.tsv'))
save_df_to_tsv(asr_cv_dev_df, os.path.join(mustc_root, 'dev_asr_mt_cv.tsv'))

# %% [markdown]
# # ST from IWSLT

# %%
root = '{}/MT_EN'.format(path_to_iwslt_mt_en)

# %%
st_audio_root = os.path.join(root, 'mt_en_parallel', 'Audio')
mt_root = os.path.join(root, 'mt_en_parallel', 'Transcription', 'Malti')
en_root = os.path.join(root, 'mt_en_parallel', 'Transcription', 'English')
new_wav_root = '{}/mt-en/data/st/wav'.format(path_to_mustc)
new_asr_wav_root = '{}/mt-en/data/asr/wav'.format(path_to_mustc)
mustc_root = path_to_mustc

# %%
def asr_make_df(mt_en_df, wav_id, speaker_id, wav, rate):
    df = pd.DataFrame(columns=['id', 'audio', 'n_frames', 'src_text', 'speaker', 'src_lang'])

    id = []
    audio = []
    n_frames = []
    src_text = []
    speaker = []
    src_lang = []

    os.makedirs(os.path.join('{}/mt-en/data/asr/align_mfat/'.format(path_to_mustc), wav_id + '_spk_{}'.format(speaker_id)), exist_ok=True)

    for q in tqdm(mt_en_df.iterrows(), total=len(mt_en_df)):
        idx, q = q[0], q[1]
        duration = q['End'] - q['Start']
        s_text = re.sub('<.*>', ' ', q['Text_y']).strip()
        if duration > 0.5 and duration < 30 and '/' not in s_text and s_text != "":
            subwav_id = wav_id + '_spk_{}_{}'.format(speaker_id, idx)
            wav_s, wav_e = int(q['Start'] * rate), int(q['End'] * rate)
            torchaudio.save(os.path.join(new_asr_wav_root, subwav_id + '.wav'), wav[wav_s : wav_e].unsqueeze(0), rate)
            torchaudio.save(os.path.join('{}/mt-en/data/asr/align_mfat/'.format(path_to_mustc), wav_id + '_spk_{}'.format(speaker_id), subwav_id + '.wav'), wav[wav_s : wav_e].unsqueeze(0), rate)
            
            id.append(subwav_id)
            audio.append('mt-en/data/asr/wav/{}.wav'.format(subwav_id))
            n_frames.append(wav_e - wav_s)
            src_text.append(s_text)
            speaker.append(q['Speaker'])
            src_lang.append('mt')

    df['id'] = id
    df['audio'] = audio
    df['n_frames'] = pd.Series(n_frames, dtype=int)
    df['src_text'] = src_text
    df['speaker'] = speaker
    df['src_lang'] = src_lang
    return df

# %%
def st_make_df(mt_en_df, wav_id, speaker_id, wav, rate, ):
    df = pd.DataFrame(columns=['id', 'audio', 'n_frames', 'src_text', 'tgt_text', 'speaker', 'src_lang', 'tgt_lang'])

    id = []
    audio = []
    n_frames = []
    src_text = []
    tgt_text = []
    speaker = []
    src_lang = []
    tgt_lang = []

    for q in tqdm(mt_en_df.iterrows(), total=len(mt_en_df)):
        idx, q = q[0], q[1]
        duration = q['End'] - q['Start']
        s_text = re.sub('<.*>', ' ', q['Text_y']).strip()
        t_text = re.sub('<.*>', ' ', q['Text_x']).strip()
        if duration > 0.5 and duration < 30 and '/' not in s_text + t_text and s_text != "" and t_text != "":
            subwav_id = wav_id + '_spk_{}_{}'.format(speaker_id, idx)
            wav_s, wav_e = int(q['Start'] * rate), int(q['End'] * rate)
            # torchaudio.save(os.path.join(new_wav_root, subwav_id + '.wav'), wav[wav_s : wav_e].unsqueeze(0), rate)
            
            id.append(subwav_id)
            audio.append('mt-en/data/st/wav/{}.wav'.format(subwav_id))
            n_frames.append(wav_e - wav_s)
            src_text.append(s_text)
            tgt_text.append(t_text)
            speaker.append(q['Speaker'])
            src_lang.append('mt')
            tgt_lang.append('en')

            print(subwav_id, q['Start'], q['End'], s_text)

    df['id'] = id
    df['audio'] = audio
    df['n_frames'] = pd.Series(n_frames, dtype=int)
    df['src_text'] = src_text
    df['tgt_text'] = tgt_text
    df['speaker'] = speaker
    df['src_lang'] = src_lang
    df['tgt_lang'] = tgt_lang
    return df

# %%
# ST DF
all_df = None
for fn in os.listdir(st_audio_root)[:1]:
    id = fn[:-4]
    try:
        en_df = load_df_from_tsv(os.path.join(en_root, id + '.tsv'))
        mt_df = load_df_from_tsv(os.path.join(mt_root, id + '.tsv'), enc='utf-16')
    except:
        print('Skip ' + fn)
        continue
    if 'Speaker' in en_df.columns:
        mt_en_df = pd.merge(en_df, mt_df, on=['Speaker', 'Start', 'End'])
    else:
        mt_en_df = pd.merge(en_df, mt_df, on=['Start', 'End'])

    wav, rate = torchaudio.load(os.path.join(st_audio_root, id + '.wav'))
    resampled_wav = torchaudio.functional.resample(wav, orig_freq=rate, new_freq=16000)

    annotators = mt_en_df['Speaker'].unique().tolist()
    if '2' in annotators[0]:
        annotators = annotators[::-1]
    print(fn, annotators)

    if wav.size(0) == 2 and len(annotators) == 2:
        for i in range(2):
            cur_df = st_make_df(mt_en_df[mt_en_df['Speaker'] == annotators[i]], id, i, resampled_wav[i], 16000)
            all_df = cur_df if all_df is None else pd.concat([all_df, cur_df], ignore_index=True)
    elif wav.size()[0] == 1 and len(annotators) == 1:
        cur_df = st_make_df(mt_en_df, id, 0, resampled_wav[0], 16000)
        all_df = cur_df if all_df is None else pd.concat([all_df, cur_df], ignore_index=True)
    elif wav.size()[0] == 2 and len(annotators) == 1:
        cur_df = st_make_df(mt_en_df, id, 0, resampled_wav[0] + resampled_wav[1], 16000)
        all_df = cur_df if all_df is None else pd.concat([all_df, cur_df], ignore_index=True)
    
    print(all_df['n_frames'].dtype)
# Out:
# Dia_Spont02_13M_14M.wav ['Annotator SP 1 ', 'Annotator SP 2 ']
# 100%|██████████| 170/170 [00:00<00:00, 4006.29it/s]
# Dia_Spont02_13M_14M_spk_0_0 0.006881827 2.245248 Il-ħobż.
# Dia_Spont02_13M_14M_spk_0_14 17.73556 19.25959 M'għandniex inħalluh haw'.
# Dia_Spont02_13M_14M_spk_0_16 21.64732 22.34847 Eħe+
# Dia_Spont02_13M_14M_spk_0_18 23.21309 24.53217 U jien ma ko...
# Dia_Spont02_13M_14M_spk_0_20 24.53217 25.60337 mhux kulħadd kien jaf.
# Dia_Spont02_13M_14M_spk_0_21 25.60337 26.69405 Jiena fil-bidu ma kontx naf
# Dia_Spont02_13M_14M_spk_0_22 26.69405 28.3586 għax li kien qed jiġri
# Dia_Spont02_13M_14M_spk_0_23 28.3586 30.20887 jiena tfajtu lura fil-ħamrija
# Dia_Spont02_13M_14M_spk_0_25 30.69995 32.10041 u kuljum nerġa' mmur
# Dia_Spont02_13M_14M_spk_0_26 32.10041 33.6001 l-iskola dejjem narah
# Dia_Spont02_13M_14M_spk_0_27 33.6001 34.68986 resaq
# Dia_Spont02_13M_14M_spk_0_28 34.68986 35.34974 pulzier
# Dia_Spont02_13M_14M_spk_0_30 35.34974 37.53992 iktar lejna.
# Dia_Spont02_13M_14M_spk_0_31 37.53992 38.82699 Kont ħa niġġennen
# Dia_Spont02_13M_14M_spk_0_32 38.82699 41.14492 da... qis... qisu qed jiġri warajja wara li faqagħli subgħajja
# Dia_Spont02_13M_14M_spk_0_34 41.14492 43.16979 qisu qed jiġri wara... warajja issa dal-kantun.
# Dia_Spont02_13M_14M_spk_0_37 43.16979 46.69109 Kull... kuljum narah pulzier mexa le... lej... lej' il-lemin.
# Dia_Spont02_13M_14M_spk_0_39 47.44094 48.35923 Ma nafx x'kien.
# Dia_Spont02_13M_14M_spk_0_40 48.35923 50.19002 Int kont qed tressqu? Min kien qed ire...
# Dia_Spont02_13M_14M_spk_0_43 51.45148 53.17306 Ma nafx min kien   għadni ma nafx s'issa
# Dia_Spont02_13M_14M_spk_0_44 53.17306 54.01055 min kien qed iressqu.
# Dia_Spont02_13M_14M_spk_0_46 54.01055 54.70591 Vera kienet tad-daħq
# Dia_Spont02_13M_14M_spk_0_47 54.70591 57.53162 għax imbagħad ġie eżatt faċċata ta' fej' konna ndu... noqogħdu bilqiegħda.
# Dia_Spont02_13M_14M_spk_0_49 58.31602 59.8644 U kull min iko...
# Dia_Spont02_13M_14M_spk_0_50 59.8644 61.22822 Kull min kien ikollu l-ħobż
# Dia_Spont02_13M_14M_spk_0_51 61.22822 62.56236 dakinhar m'għoġbux+
# Dia_Spont02_13M_14M_spk_0_52 62.56236 63.52088 jew+
# Dia_Spont02_13M_14M_spk_0_53 63.52088 65.2056 ħażin+ jew ma nafx
# Dia_Spont02_13M_14M_spk_0_55 66.59145 68.44704 ma jkunx irid jieklu kien jitfa' l-ħobż
# Dia_Spont02_13M_14M_spk_0_56 68.44704 69.34783 fuq il-kantun.
# Dia_Spont02_13M_14M_spk_0_59 70.94421 72.23453 Ee kien qisu altar.
# Dia_Spont02_13M_14M_spk_0_61 72.23453 73.328 Allura konna ?qisnu
# Dia_Spont02_13M_14M_spk_0_63 74.50053 76.06375 ta' studenti
# Dia_Spont02_13M_14M_spk_0_69 81.34328 82.18076 Eħe.
# Dia_Spont02_13M_14M_spk_0_73 83.58353 84.46484 Il-ħamiem.
# Dia_Spont02_13M_14M_spk_0_77 88.83801 90.23476 I+va kienet ċajta.
# Dia_Spont02_13M_14M_spk_0_82 94.62161 96.63743 'flok nistudjaw ee 'ġifieri.
# Dia_Spont02_13M_14M_spk_0_84 96.63743 98.78518 Konna   nitbaħanħu
# Dia_Spont02_13M_14M_spk_0_85 98.78518 100.4852 madwar il-kantun.
# Dia_Spont02_13M_14M_spk_0_88 101.2805 102.342 Mm.
# Dia_Spont02_13M_14M_spk_0_91 104.4874 105.9043 Jew 'il sħabna stess.
# Dia_Spont02_13M_14M_spk_0_99 110.0832 111.3248 Darba
# Dia_Spont02_13M_14M_spk_0_101 111.3248 112.3951 konna qegħdin
# Dia_Spont02_13M_14M_spk_0_105 114.1716 115.8856 niżżuffjettaw mal... mal-kantun
# Dia_Spont02_13M_14M_spk_0_107 115.8856 117.0374 bħas-soltu
# Dia_Spont02_13M_14M_spk_0_109 117.5925 120.1324 u għaddiet xi għalliema
# Dia_Spont02_13M_14M_spk_0_111 120.1324 120.9212 u
# Dia_Spont02_13M_14M_spk_0_113 121.5352 122.7865 u ġiet tgħajjat.
# Dia_Spont02_13M_14M_spk_0_118 126.9176 127.5847 Mhm.
# Dia_Spont02_13M_14M_spk_0_132 141.9396 143.1325 M'aħniex ħa nerġgħu nagħmluha.
# Dia_Spont02_13M_14M_spk_0_134 143.7477 144.868 Imbagħad l-għada erġajna għamilnieha.
# Dia_Spont02_13M_14M_spk_0_143 157.8841 158.7026 Ija.
# Dia_Spont02_13M_14M_spk_0_152 168.6099 169.608 Il... id... i...
# Dia_Spont02_13M_14M_spk_0_154 169.944 171.2652 Il-ħabib tagħna Dylan
# Dia_Spont02_13M_14M_spk_0_159 175.1206 177.5389 u konna mmorru fi klassi mhux qed tintuża
# Dia_Spont02_13M_14M_spk_0_160 177.5389 178.9517 li... kienu już... u
# Dia_Spont02_13M_14M_spk_0_162 178.9517 180.4611 kienu rari jużawha
# Dia_Spont02_13M_14M_spk_0_167 183.5829 185.3764 Eħe konna ?naqgħu plakka
# Dia_Spont02_13M_14M_spk_0_171 188.564 190.6334 Nitfgħu   li... f... [i]l-frott.
# Dia_Spont02_13M_14M_spk_0_173 190.6334 193.1816 Xi kultant naq'a vodka.
# Dia_Spont02_13M_14M_spk_0_176 196.9577 198.6181 ħafna mid-drabi eħe.
# Dia_Spont02_13M_14M_spk_0_183 203.7223 207.5497 Ma konniex studenti eżemplari dak iż-żmien imma wasalna b'xi mod.
# Dia_Spont02_13M_14M_spk_0_189 212.733 215.6804 Ifhem   ta... ta... taz-zalzett.
# Dia_Spont02_13M_14M_spk_0_194 219.9564 221.6101 Ma kellix aptit immur
# Dia_Spont02_13M_14M_spk_0_195 221.6101 223.0173 u sa mnalla ma mortx.
# Dia_Spont02_13M_14M_spk_0_197 223.0173 226.412 Konna qegħdin fl-istess post ta'   fej' il-kantun ma nafx
# Dia_Spont02_13M_14M_spk_0_230 273.0425 273.8855 sura.
# Dia_Spont02_13M_14M_spk_0_243 290.5426 293.0258 Ta' Dylan kien jew ta' Ethan? Naħseb ta' Ethan.
# Dia_Spont02_13M_14M_spk_0_248 294.5311 295.5552 Ta' Kyle kien.
# Dia_Spont02_13M_14M_spk_0_250 295.935 297.9947 Tagħna nafu li kien hemm   'iġifieri tiegħu
# Dia_Spont02_13M_14M_spk_0_253 297.9947 299.3587 kien u kien
# Dia_Spont02_13M_14M_spk_0_299 360.4452 362.1055 U kien hemm Dylan ukoll erbgħa.
# Dia_Spont02_13M_14M_spk_0_303 366.082 368.2633 Iva erbgħa le tlieta għedt ilħaqt ħriġt
# Dia_Spont02_13M_14M_spk_0_305 369.2636 370.2033 Ee
# Dia_Spont02_13M_14M_spk_0_309 373.6076 374.3623 Fhimt.
# Dia_Spont02_13M_14M_spk_0_342 412.1337 413.1713 Jien niftakar
# Dia_Spont02_13M_14M_spk_0_343 413.1713 415.4111 għax kienu marru &jixxu daw' u damu
# Dia_Spont02_13M_14M_spk_0_345 415.4111 416.6242 ħafna
# Dia_Spont02_13M_14M_spk_0_346 416.6242 418.2456 biex &jixxu biċċa ?we...
# Dia_Spont02_13M_14M_spk_0_347 418.2456 419.5559 Kemm qed idumu?
# Dia_Spont02_13M_14M_spk_0_348 419.5559 421.5425 Jien ma ridtx immur għax ma   kelli l-ikel.
# Dia_Spont02_13M_14M_spk_0_349 421.5425 423.0672 Ħa jdumu mbagħad
# Dia_Spont02_13M_14M_spk_0_357 433.3898 434.2954 Ma niftakarx.
# Dia_Spont02_13M_14M_spk_0_364 443.6961 445.5317 [U]mbagħad tlaqt mill-iskola.
# Dia_Spont02_13M_14M_spk_0_377 458.6545 461.5361 Iva le kesħin ma konniex imma
# Dia_Spont02_13M_14M_spk_0_382 465.5872 466.2056 Sew.
# Dia_Spont02_13M_14M_spk_0_394 481.5102 482.1334 mm
# Dia_Spont02_13M_14M_spk_0_426 525.5493 526.2261 Le.
# Dia_Spont02_13M_14M_spk_0_442 550.4562 552.079 Għax Ethan jirrispondi.
# Dia_Spont02_13M_14M_spk_0_444 553.6216 555.9352 U+ anka dak il-ħin   'ġifieri dej...
# 100%|██████████| 287/287 [00:00<00:00, 3620.14it/s]
# Dia_Spont02_13M_14M_spk_1_1 0.007271497 1.02 Irrekordjata.
# Dia_Spont02_13M_14M_spk_1_3 3.337748 5.090631 Mela [i]l-kantun sewwa
# Dia_Spont02_13M_14M_spk_1_6 6.25335 8.23995 wara li faqa' subgħajh
# Dia_Spont02_13M_14M_spk_1_7 8.23995 10.00644 għedna orrajt   x'ħa nagħmlu bih dal-kantun?
# Dia_Spont02_13M_14M_spk_1_8 10.00644 11.98655 u lo... erġajna tfajnieh lura f'postu+.
# Dia_Spont02_13M_14M_spk_1_9 11.98655 13.22717 Em imma mbagħad
# Dia_Spont02_13M_14M_spk_1_10 13.22717 15.18162 ta' studenti bravi li konna għedna dan
# Dia_Spont02_13M_14M_spk_1_13 16.57744 18.99346 Dan mhux... m'għandniex inħalluh fejn qiegħed.
# Dia_Spont02_13M_14M_spk_1_15 18.99346 22.42 Għedna orrajt ejja nitfgħuh ik... ik... iktar viċin tagħna speċi
# Dia_Spont02_13M_14M_spk_1_19 23.5 24.59778 taħt siġra.
# Dia_Spont02_13M_14M_spk_1_24 30.06418 30.80429 Eżatt
# Dia_Spont02_13M_14M_spk_1_41 49.17134 51.32488 Le mhux jien mhux jien kont qed inressqu.
# Dia_Spont02_13M_14M_spk_1_48 57.52443 58.14281 Eżatt
# Dia_Spont02_13M_14M_spk_1_54 65.84647 67.15139 Ma jkunx irid jieklu ħa
# Dia_Spont02_13M_14M_spk_1_57 68.44704 69.72276 fuq... fuq il-kantun.
# Dia_Spont02_13M_14M_spk_1_58 69.72276 72.19557 Għax kien qisu altar hekk qiegħed hemm taħt is-siġra.
# Dia_Spont02_13M_14M_spk_1_60 72.19557 72.97742 mm kantun
# Dia_Spont02_13M_14M_spk_1_62 73.51789 74.46737 li waqa' fuq subgħajh.
# Dia_Spont02_13M_14M_spk_1_68 81.11651 82.40474 u hekk jiekluhom 'ġifieri
# Dia_Spont02_13M_14M_spk_1_70 82.40474 83.1692 kienet hekk.
# Dia_Spont02_13M_14M_spk_1_72 83.52998 84.6937 Uwija [u]mbagħad
# Dia_Spont02_13M_14M_spk_1_74 84.6937 86.73432 għamilnieha ċajta speċi li aħna
# Dia_Spont02_13M_14M_spk_1_75 86.73432 88.24375 naduraw il-ħobż divin.
# Dia_Spont02_13M_14M_spk_1_76 88.24375 90.87262 Għax nitfgħu l-ħobż fuq il+- dana hekk
# Dia_Spont02_13M_14M_spk_1_79 91.42283 93.52212 u konna noqogħdu nduru mal... mal... mal... mal-artal
# Dia_Spont02_13M_14M_spk_1_83 96.60381 98.94585 Konna nwaddbu l-affarijiet fuqu 'iġifieri.
# Dia_Spont02_13M_14M_spk_1_90 104.1549 105.3736 U darba konna qed nagħmlu
# Dia_Spont02_13M_14M_spk_1_92 105.768 106.3961 Iva.
# Dia_Spont02_13M_14M_spk_1_94 106.6692 107.4532 Iva iva.
# Dia_Spont02_13M_14M_spk_1_95 107.4532 108.5721 Darba ?żammew
# Dia_Spont02_13M_14M_spk_1_98 108.5721 109.5021 Kont
# Dia_Spont02_13M_14M_spk_1_104 113.3494 114.9361 Tal-Ingliż.
# Dia_Spont02_13M_14M_spk_1_116 124.8223 126.7229 Ii x'diżgrazzja
# Dia_Spont02_13M_14M_spk_1_117 126.7229 128.4465 x'qed tagħmlu hemm?
# Dia_Spont02_13M_14M_spk_1_120 128.4465 130.1248 ?Pappa ma' kantun?
# Dia_Spont02_13M_14M_spk_1_121 130.1248 131.4979 Toqogħdu tħammġuh?
# Dia_Spont02_13M_14M_spk_1_122 131.4979 133.4543 Ii misskom tistħu.
# Dia_Spont02_13M_14M_spk_1_125 133.4543 135.9179 Misskom tistħu ta' studenti l'intom hawnhekk
# Dia_Spont02_13M_14M_spk_1_126 135.9179 137.4 u tagħmlu daw' il-ħmerijiet.
# Dia_Spont02_13M_14M_spk_1_130 139.9745 141.26 għedna uu
# Dia_Spont02_13M_14M_spk_1_133 143.5042 144.2735 ee
# Dia_Spont02_13M_14M_spk_1_136 146.7039 149.2289 Le le qaltilna... qaltilna oqogħdu haw'
# Dia_Spont02_13M_14M_spk_1_137 149.2289 150.1979 ħa nġib
# Dia_Spont02_13M_14M_spk_1_138 150.1979 151.24 il-prinċipal.
# Dia_Spont02_13M_14M_spk_1_140 152.7817 154.4514 Telqet għall-prinċipal u tlaqna niġru.
# Dia_Spont02_13M_14M_spk_1_144 158.5614 160.8663 Ija issa naħseb stejjer oħra wisq
# Dia_Spont02_13M_14M_spk_1_145 160.8663 163.3058 kriminali biex ngħiduhom.
# Dia_Spont02_13M_14M_spk_1_163 179.9596 181.1282 Eżatt eża...
# Dia_Spont02_13M_14M_spk_1_175 195.2716 197.4822 Iv... le mhux xi kultant naħseb iktar
# Dia_Spont02_13M_14M_spk_1_177 197.4822 198.6851 iktar bil-kontra
# Dia_Spont02_13M_14M_spk_1_179 198.6851 200.3345 xi kultant mhux mingħajr vodka.
# Dia_Spont02_13M_14M_spk_1_180 200.3345 202.4167 Ajma
# Dia_Spont02_13M_14M_spk_1_184 206.0741 206.8388 Le le
# Dia_Spont02_13M_14M_spk_1_185 207.5529 208.6826 ma konniex
# Dia_Spont02_13M_14M_spk_1_186 208.6826 209.8268 &qax xejn.
# Dia_Spont02_13M_14M_spk_1_188 210.88 212.4993 Ee x'hemm iktar tad-daħq?
# Dia_Spont02_13M_14M_spk_1_190 215.5675 217.5298 Taz-zalzett taz-zalzett.
# Dia_Spont02_13M_14M_spk_1_192 217.5298 219.4939 Mela jien kont hemm
# Dia_Spont02_13M_14M_spk_1_193 219.4939 220.9838 jien kont... mela mela
# Dia_Spont02_13M_14M_spk_1_200 230.6003 231.9783 speċi
# Dia_Spont02_13M_14M_spk_1_201 231.9783 233.7706 ma nafx jekk għadhiex hekk bħalissa imma
# Dia_Spont02_13M_14M_spk_1_206 240.2974 241.5297 U qabadna l-ġuħ
# Dia_Spont02_13M_14M_spk_1_207 241.5297 243.0099 u għedna uwija ejja mmorru &nixxu
# Dia_Spont02_13M_14M_spk_1_208 243.0099 244.4025 &qas... &qas jiena le le
# Dia_Spont02_13M_14M_spk_1_209 244.4025 246.918 mar wieħed minna konna erbgħa
# Dia_Spont02_13M_14M_spk_1_210 246.918 248.2783 u mar wieħed minna.
# Dia_Spont02_13M_14M_spk_1_211 248.2783 251.2012 U *t-tlieta oħra jin... jin... inkluż jiena 'iġifieri
# Dia_Spont02_13M_14M_spk_1_213 251.2012 252.7329 tlaqna niġru warajh.
# Dia_Spont02_13M_14M_spk_1_221 262.5725 264.3643 ieħor minn dawn it-tlieta biex niftehmu
# Dia_Spont02_13M_14M_spk_1_223 264.3643 266.2876 ħaduhielu u tlaqna niġru iktar.
# Dia_Spont02_13M_14M_spk_1_229 272.3705 273.0578 kappella.
# Dia_Spont02_13M_14M_spk_1_232 275.3185 276.8571 naqra spazjuż.
# Dia_Spont02_13M_14M_spk_1_235 277.7973 280.4807 U+ dħalna niġru ġod... ġod... di... da...
# Dia_Spont02_13M_14M_spk_1_237 281.6736 282.7589 Kien hemm erbgħa
# Dia_Spont02_13M_14M_spk_1_240 283.7036 285.2081 Jiena
# Dia_Spont02_13M_14M_spk_1_244 290.8234 292.3249 T... t...
# Dia_Spont02_13M_14M_spk_1_247 293.3231 294.7794 Le ta' Kyle kien.
# Dia_Spont02_13M_14M_spk_1_249 294.7794 296.2645 Ta' Kyle kien.
# Dia_Spont02_13M_14M_spk_1_252 297.1725 299.2273 Ee ħeqq mela iva tiegħu kien.
# Dia_Spont02_13M_14M_spk_1_254 299.2273 300.9987 Mela mela jiena
# Dia_Spont02_13M_14M_spk_1_260 305.4818 307.4051 Imbagħad daħal ieħor warajna
# Dia_Spont02_13M_14M_spk_1_262 309.8647 310.9943 u qagħad jgħodd.
# Dia_Spont02_13M_14M_spk_1_271 325.7923 327.7599 ġUħmbagħad f'daqqa waħda
# Dia_Spont02_13M_14M_spk_1_273 327.7599 329.5 qagħad kwiet
# Dia_Spont02_13M_14M_spk_1_276 333.4176 334.2409 oqogħdu kwieti.
# Dia_Spont02_13M_14M_spk_1_277 334.2409 335.3073 U nisimgħu
# Dia_Spont02_13M_14M_spk_1_279 336.3581 338.098 X'qed tagħmlu hemm intom? X'qed tagħmlu hemm?
# Dia_Spont02_13M_14M_spk_1_281 338.6901 340.3554 U aħna
# Dia_Spont02_13M_14M_spk_1_282 340.3554 342.166 U... u daħal xi ħadd hekk u qalilna
# Dia_Spont02_13M_14M_spk_1_283 342.166 343.1836 oħorġu minn hemm ejja.
# Dia_Spont02_13M_14M_spk_1_285 344.9525 347.5299 U qalu... u qal... qal... għajjat
# Dia_Spont02_13M_14M_spk_1_288 349.1898 350.8843 u ħareġ l-ewwel wieħed.
# Dia_Spont02_13M_14M_spk_1_290 351.8027 352.7814 Imbagħad ħriġt jiena.
# Dia_Spont02_13M_14M_spk_1_291 353.4046 354.16 Hemm iktar?
# Dia_Spont02_13M_14M_spk_1_294 355.2473 358.3106 [U]mbagħad ħareġ l-ieħor
# Dia_Spont02_13M_14M_spk_1_296 358.3106 359.1286 Fl-uffiċċju tiegħi.
# Dia_Spont02_13M_14M_spk_1_298 360.2193 361.9108 Imxejna sal-uffiċċju tiegħu ija
# Dia_Spont02_13M_14M_spk_1_300 361.9108 363.464 erb... eżatt eżatt.
# Dia_Spont02_13M_14M_spk_1_302 364.6359 367.1766 Eżatt eżatt eżatt mhux erbgħa semmejt? Eżatt.
# Dia_Spont02_13M_14M_spk_1_304 367.8597 370.0751 Tlieta għedt ħa... ħriġna u l-ieħor ħareġ minn
# Dia_Spont02_13M_14M_spk_1_310 373.7926 375.5796 Imbagħad dħalna fl-uffiċċju
# Dia_Spont02_13M_14M_spk_1_311 375.5796 376.9714 u qalilna
# Dia_Spont02_13M_14M_spk_1_312 376.9714 378.4809 qalilna pastażi intom.
# Dia_Spont02_13M_14M_spk_1_324 390.2523 391.2067 Qallu
# Dia_Spont02_13M_14M_spk_1_325 391.9301 393.1084 Jien nagħmel li rrid haw'
# Dia_Spont02_13M_14M_spk_1_329 394.9712 395.6812 Tahielu
# Dia_Spont02_13M_14M_spk_1_331 397.4855 399.0198 u għamillu stilla
# Dia_Spont02_13M_14M_spk_1_332 399.0198 399.84 fuqha.
# Dia_Spont02_13M_14M_spk_1_334 401.7615 403.4075 Tkompli l-istorja jiġifieri
# Dia_Spont02_13M_14M_spk_1_336 404.5618 405.7334 u+
# Dia_Spont02_13M_14M_spk_1_337 405.7334 407.8806 għaddiet ifhem inżilna lura
# Dia_Spont02_13M_14M_spk_1_338 407.8806 410.8088 jien kont qed nidħaq &jiġieri kont qed immut bid-daħq jiena jien
# Dia_Spont02_13M_14M_spk_1_340 410.8088 412.1191 billi jgħajjat jgħajjat miegħi xi ħadd
# Dia_Spont02_13M_14M_spk_1_341 412.1191 413.1518 ma waqgħatx id-dinja.
# Dia_Spont02_13M_14M_spk_1_350 422.2483 424.6001 Inżilna morna fejnkom
# Dia_Spont02_13M_14M_spk_1_352 424.6001 426.6991 u għedna l-istorja x'ġara
# Dia_Spont02_13M_14M_spk_1_354 426.6991 429.3568 u t-tfajliet tagħna kulħadd kellu
# Dia_Spont02_13M_14M_spk_1_355 429.3568 432.1096 eħe le naħseb forsi Ethan kien għadu mhux ma' Marilyn?
# Dia_Spont02_13M_14M_spk_1_358 434.2372 436.0242 Imma uwija Gabby niftakarha
# Dia_Spont02_13M_14M_spk_1_359 436.0242 437.8745 ii issa x'ħa tagħmel?
# Dia_Spont02_13M_14M_spk_1_362 438.7467 440.0788 Issa x'ħa tagħmel issa jekk
# Dia_Spont02_13M_14M_spk_1_363 440.0788 442.8848 jirrabja miegħek x'ħa tagħmel? Jekk ikeċċuk mill-iskola.
# Dia_Spont02_13M_14M_spk_1_365 443.7058 444.7722 Għaddejja hekk.
# Dia_Spont02_13M_14M_spk_1_366 444.7722 446.4471 [U]mbagħad tlaqt waħdi imma uwija
# Dia_Spont02_13M_14M_spk_1_369 447.19 448.4516 dik ħaġo... dik storja oħra.
# Dia_Spont02_13M_14M_spk_1_372 451.3626 452.483 l... hekk ?loħdaw
# Dia_Spont02_13M_14M_spk_1_373 452.483 454.679 kwieti konna siġi... speċi dak iż-żmien ma kon... ma ko...
# Dia_Spont02_13M_14M_spk_1_374 454.679 457.0484 kwieti kwieti u mhux kesħin.
# Dia_Spont02_13M_14M_spk_1_376 458.5182 459.8368 Boloh mhux kesħin.
# Dia_Spont02_13M_14M_spk_1_378 459.8368 461.7893 Boloh ma k... ma kon... qatt ma konna
# Dia_Spont02_13M_14M_spk_1_379 461.7893 463.2846 kesħin dejjem boloh konna.
# Dia_Spont02_13M_14M_spk_1_381 464.2628 466.2056 Boloh konna boloh 'iġifieri.
# Dia_Spont02_13M_14M_spk_1_383 466.2056 467.5353 U kulħadd jinkwieta
# Dia_Spont02_13M_14M_spk_1_384 467.5353 469.1275 u jiena le tinkwetawx tinkwetawx.
# Dia_Spont02_13M_14M_spk_1_385 469.1275 471.3191 Għaddew xi [k]lett ijiem jew erbgħa ma nafx kemm għadda u
# Dia_Spont02_13M_14M_spk_1_386 471.3191 473.9793 u qaluln... u ċemplilna ille... il-viċi
# Dia_Spont02_13M_14M_spk_1_388 474.9644 476.5703 qalilna mmorru l-uffiċċju tiegħu.
# Dia_Spont02_13M_14M_spk_1_393 481.4782 483.7391 sal-uffiċċju dħalna fl-uffiċċju
# Dia_Spont02_13M_14M_spk_1_395 483.7391 485.2232 għamilna linja
# Dia_Spont02_13M_14M_spk_1_396 485.2232 486.7452 u ġie jkellimna.
# Dia_Spont02_13M_14M_spk_1_398 486.7452 488.365 X'għamiltu ee intom?
# Dia_Spont02_13M_14M_spk_1_399 488.365 491.0625 X'għamiltu? x'għamiltu? U jħares f'għajnejna hekk irrabjat.
# Dia_Spont02_13M_14M_spk_1_400 491.0625 494.009 Nippruvaw mħ... inżommu d-daħq lura 'iġifieri.
# Dia_Spont02_13M_14M_spk_1_402 496.4382 497.2611 *Dak mhux postijiet
# Dia_Spont02_13M_14M_spk_1_403 497.2611 499.0244 fej' toqogħdu tiċċajtaw fihom ta.
# Dia_Spont02_13M_14M_spk_1_404 499.0244 499.9301 Dak ikun hemm
# Dia_Spont02_13M_14M_spk_1_405 499.9301 501.6927 dak huwa post ta' serenità.
# Dia_Spont02_13M_14M_spk_1_408 504.8305 506.809 Post fej' għandek tieħu l-ħin tiegħek
# Dia_Spont02_13M_14M_spk_1_409 506.809 507.7759 tużah
# Dia_Spont02_13M_14M_spk_1_410 507.7759 509.2902 għas-sanità u daqshekk.
# Dia_Spont02_13M_14M_spk_1_414 514.6209 515.5996 Sewwa ftehmna?
# Dia_Spont02_13M_14M_spk_1_419 517.5102 519.2144 U+ ħsibna li ħa... ħa jibgħatna 'l hemm.
# Dia_Spont02_13M_14M_spk_1_420 519.2144 519.8481 [U]mbagħad
# Dia_Spont02_13M_14M_spk_1_421 519.8481 521.5494 qabad il-karta li kiteb
# Dia_Spont02_13M_14M_spk_1_422 521.5494 523.5259 il... l-għalliem l-ieħor li k... dana u sab
# Dia_Spont02_13M_14M_spk_1_425 525.4714 526.9468 U qallu inti
# Dia_Spont02_13M_14M_spk_1_429 530.2125 532.5594 Toqgħodx tidħaq inti.
# Dia_Spont02_13M_14M_spk_1_431 532.5594 533.7542 Qallu qallu
# Dia_Spont02_13M_14M_spk_1_433 536.5289 538.0205 ?X'jiġi qallu
# Dia_Spont02_13M_14M_spk_1_435 540.4979 541.242 Qallu
# Dia_Spont02_13M_14M_spk_1_436 541.242 542.4924 qallu
# Dia_Spont02_13M_14M_spk_1_437 542.4924 544.1674 toqgħodx titkessaħ magħna inti ta
# Dia_Spont02_13M_14M_spk_1_438 544.1674 545.0687 għax inkeċċuk 'l hemm.
# Dia_Spont02_13M_14M_spk_1_440 547.2352 549.251 qed nitkessaħ jiena m'għamilt xej'.
# Dia_Spont02_13M_14M_spk_1_441 549.251 550.4562 Qallu oqgħod kwiet.
# Dia_Spont02_13M_14M_spk_1_443 551.7081 553.5535 U hu ma jirrispondix 'iġifieri.
# Dia_Spont02_13M_14M_spk_1_445 555.6333 556.3344 Iv... iva
# Dia_Spont02_13M_14M_spk_1_446 556.3344 558.1254 U+wija mbagħad tlaqna 'l hemm u
# Dia_Spont02_13M_14M_spk_1_447 558.1254 559.5091 ifhem qatt m'erġajna
# Dia_Spont02_13M_14M_spk_1_449 561.8901 563.4579 u qgħadna nxengluh 'iġifieri.
# Dia_Spont02_13M_14M_spk_1_451 564.1378 565.3794 Minn daqshekk ħadmet
# Dia_Spont02_13M_14M_spk_1_452 565.3794 567.5928 lis... lis... l-istrateġija tal-viċi.
# Dia_Spont02_13M_14M_spk_1_454 567.5928 568.754 Għamilna affarijiet oħra imma.
# Dia_Spont02_13M_14M_spk_1_455 570.136 571.4965 Għamilna ħafna affarijiet oħra.
# int64

# %%
st_iwslt_df = all_df.copy()

# %%
# ASR DF
all_df = None
for fn in os.listdir(st_audio_root):
    id = fn[:-4]
    try:
        en_df = load_df_from_tsv(os.path.join(en_root, id + '.tsv'))
        mt_df = load_df_from_tsv(os.path.join(mt_root, id + '.tsv'), enc='utf-16')
    except:
        print('Skip ' + fn)
        continue
    if 'Speaker' in en_df.columns:
        mt_en_df = pd.merge(en_df, mt_df, on=['Speaker', 'Start', 'End'])
    else:
        mt_en_df = pd.merge(en_df, mt_df, on=['Start', 'End'])

    wav, rate = torchaudio.load(os.path.join(st_audio_root, id + '.wav'))
    resampled_wav = torchaudio.functional.resample(wav, orig_freq=rate, new_freq=16000)

    annotators = mt_en_df['Speaker'].unique().tolist()
    if '2' in annotators[0]:
        annotators = annotators[::-1]
    print(fn, annotators)

    if wav.size(0) == 2 and len(annotators) == 2:
        for i in range(2):
            cur_df = asr_make_df(mt_en_df[mt_en_df['Speaker'] == annotators[i]], id, i, resampled_wav[i], 16000)
            all_df = cur_df if all_df is None else pd.concat([all_df, cur_df], ignore_index=True)
    elif wav.size()[0] == 1 and len(annotators) == 1:
        cur_df = asr_make_df(mt_en_df, id, 0, resampled_wav[0], 16000)
        all_df = cur_df if all_df is None else pd.concat([all_df, cur_df], ignore_index=True)
    elif wav.size()[0] == 2 and len(annotators) == 1:
        cur_df = asr_make_df(mt_en_df, id, 0, resampled_wav[0] + resampled_wav[1], 16000)
        all_df = cur_df if all_df is None else pd.concat([all_df, cur_df], ignore_index=True)
    
    print(all_df['n_frames'].dtype)
# Out:
# Dia_Spont02_13M_14M.wav ['Annotator SP 1 ', 'Annotator SP 2 ']
# 100%|██████████| 170/170 [00:00<00:00, 1835.54it/s]
# 100%|██████████| 287/287 [00:00<00:00, 1946.97it/s]
# int64
# Dia_Task_MMap03_13F_10M.wav ['Spk 1 Annotator ', 'Spk 2 Annotator ']
# 100%|██████████| 76/76 [00:00<00:00, 1189.12it/s]
# 100%|██████████| 41/41 [00:00<00:00, 329.33it/s]
# int64
# Dia_Task_Pics01_14F_03M.wav ['Spk 1 Annotator ', 'Spk 2 Annotator ']
# 100%|██████████| 500/500 [00:00<00:00, 3925.80it/s]
# 100%|██████████| 450/450 [00:00<00:00, 28187.53it/s]
# int64
# Dia_Task_Pics02_13F_10M.wav ['Spk 1 Annotator ', 'Spk 2 Annotator ']
# 100%|██████████| 85/85 [00:00<00:00, 1190.77it/s]
# 100%|██████████| 81/81 [00:00<00:00, 1544.49it/s]
# int64
# Dia_Task_Pics02_14F_03M.wav ['Spk 1 Annotator ', 'Spk 2 Annotator ', '2 ']
# int64
# Dia_Task_Pics03_01F_06M.wav ['Spk 1 Annotator ', 'Spk 2 Annotator ']
# 100%|██████████| 84/84 [00:00<00:00, 759.25it/s]
# 100%|██████████| 97/97 [00:00<00:00, 20788.28it/s]
# int64
# Mono_Discuss_Topic02_03M.wav ['Annotator ']
# 100%|██████████| 153/153 [00:00<00:00, 1226.29it/s]
# int64
# Mono_Discuss_Topic03_07M.wav ['Annotator ']
# 100%|██████████| 81/81 [00:00<00:00, 1237.77it/s]
# int64
# Mono_Discuss_Topic04_03M.wav ['Annotator ']
# 100%|██████████| 65/65 [00:00<00:00, 763.72it/s]
# int64
# Mono_Discuss_Topic05_02F.wav ['SP1 ']
# 100%|██████████| 42/42 [00:00<00:00, 2181.61it/s]
# int64
# Mono_Discuss_Topic06_01M.wav ['Annotator ']
# 100%|██████████| 115/115 [00:00<00:00, 949.87it/s]
# int64
# Mono_Recipe_05M.wav ['1', 'SP1 ']
# int64
# Mono_Recipe_17F.wav ['SP1 ']
# 100%|██████████| 22/22 [00:00<00:00, 455.02it/s]
# int64
# Mono_Recipe_22F.wav ['1', 'Annotator ']
# int64
# Mono_Retell_Vid02_21F.wav ['Annotator ']
# 100%|██████████| 48/48 [00:00<00:00, 594.52it/s]
# int64
# Mono_Spont01_21F.wav ['Annotator ']
# 100%|██████████| 11/11 [00:00<00:00, 475.43it/s]
# int64
# Skip Mono_Spont01_22F.wav
# Mono_Task_MMap02_13M.wav ['Annotator ']
# 100%|██████████| 174/174 [00:00<00:00, 1039.22it/s]
# int64

# %%
asr_iwslt_df = all_df.copy()

# %%
split_ratio = [0.9, 0.1]
n_sample = len(asr_iwslt_df)
indices = list(range(n_sample))
random.shuffle(indices)
asr_iwslt_train_df = asr_iwslt_df.iloc[indices[:int(n_sample * split_ratio[0])]].sort_index().copy()
asr_iwslt_dev_df = asr_iwslt_df.iloc[indices[int(n_sample * split_ratio[0]):]].sort_index().copy()

# %%
save_df_to_tsv(asr_iwslt_train_df, os.path.join(mustc_root, 'train_asr_mt_iwslt.tsv'))
save_df_to_tsv(asr_iwslt_dev_df, os.path.join(mustc_root, 'dev_asr_mt_iwslt.tsv'))

# %%
st_iwslt_df
# Out:
#                                   id  \
# 0        Dia_Spont02_13M_14M_spk_0_0
# 1       Dia_Spont02_13M_14M_spk_0_14
# 2       Dia_Spont02_13M_14M_spk_0_16
# 3       Dia_Spont02_13M_14M_spk_0_18
# 4       Dia_Spont02_13M_14M_spk_0_20
# ...                              ...
# 1106  Mono_Task_MMap02_13M_spk_0_161
# 1107  Mono_Task_MMap02_13M_spk_0_163
# 1108  Mono_Task_MMap02_13M_spk_0_166
# 1109  Mono_Task_MMap02_13M_spk_0_168
# 1110  Mono_Task_MMap02_13M_spk_0_170
#
#                                                   audio  n_frames  \
# 0     mt-en/data/st/wav/Dia_Spont02_13M_14M_spk_0_0.wav     35813
# 1     mt-en/data/st/wav/Dia_Spont02_13M_14M_spk_0_14...     24385
# 2     mt-en/data/st/wav/Dia_Spont02_13M_14M_spk_0_16...     11218
# 3     mt-en/data/st/wav/Dia_Spont02_13M_14M_spk_0_18...     21105
# 4     mt-en/data/st/wav/Dia_Spont02_13M_14M_spk_0_20...     17139
# ...                                                 ...       ...
# 1106  mt-en/data/st/wav/Mono_Task_MMap02_13M_spk_0_1...     71012
# 1107  mt-en/data/st/wav/Mono_Task_MMap02_13M_spk_0_1...    124963
# 1108  mt-en/data/st/wav/Mono_Task_MMap02_13M_spk_0_1...     78795
# 1109  mt-en/data/st/wav/Mono_Task_MMap02_13M_spk_0_1...    115712
# 1110  mt-en/data/st/wav/Mono_Task_MMap02_13M_spk_0_1...    108206
#
#                                                src_text  \
# 0                                              Il-ħobż.
# 1                            M'għandniex inħalluh haw'.
# 2                                                  Eħe+
# 3                                       U jien ma ko...
# 4                                mhux kulħadd kien jaf.
# ...                                                 ...
# 1106  mela... mela dik &għadna kif iffaċilitajna ix-...
# 1107  Kif ukoll imbagħad però realistikament jekk......
# 1108  jekk dawn qegħdin jikkomunikaw kollha flimkien...
# 1109  Imbagħad jekk ner... n... naqbdu dan l-argumen...
# 1110  Seta' jgħidli li+ artisti forsi robotiċi se jm...
#
#                                                tgt_text          speaker  \
# 0                                            The bread.  Annotator SP 1
# 1                          We should not leave it here.  Annotator SP 1
# 2                                                    Ok  Annotator SP 1
# 3                                   And I didn't kno...  Annotator SP 1
# 4                                    not everyone knew.  Annotator SP 1
# ...                                                 ...              ...
# 1106  so... so that's how we facilitated the work of...       Annotator
# 1107  As well as then however realistically if... le...       Annotator
# 1108  if they are all communicating together they wi...       Annotator
# 1109  Then if we... n... We pick the argument of the...       Annotator
# 1110  Could he tell me if+ maybe robotic artists wil...       Annotator
#
#      src_lang tgt_lang
# 0          mt       en
# 1          mt       en
# 2          mt       en
# 3          mt       en
# 4          mt       en
# ...       ...      ...
# 1106       mt       en
# 1107       mt       en
# 1108       mt       en
# 1109       mt       en
# 1110       mt       en
#
# [1111 rows x 8 columns]

# %%
split_ratio = [0.8, 0.1, 0.1]

# %%
n_sample = len(st_iwslt_df)
indices = list(range(n_sample))
random.shuffle(indices)

# %%
st_train_df = all_df.iloc[indices[:int(n_sample * split_ratio[0])]].sort_index().copy()
st_dev_df = all_df.iloc[indices[int(n_sample * split_ratio[0]):int(n_sample * (split_ratio[0] + split_ratio[1]))]].sort_index().copy()
st_test_df = all_df.iloc[indices[int(n_sample * (split_ratio[0] + split_ratio[1])):]].sort_index().copy()

# %%
save_df_to_tsv(st_train_df, os.path.join(mustc_root, 'train_st_mt_en.tsv'))
save_df_to_tsv(st_dev_df, os.path.join(mustc_root, 'dev_st_mt_en.tsv'))
save_df_to_tsv(st_test_df, os.path.join(mustc_root, 'test_st_mt_en.tsv'))

# %%
st_train_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/siqiouyang/work/projects/ConST/ConST/prepare_data/mt_en.ipynb Cell 37 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Blei1/home/siqiouyang/work/projects/ConST/ConST/prepare_data/mt_en.ipynb#X51sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> st_train_df
#
# NameError: name 'st_train_df' is not defined
